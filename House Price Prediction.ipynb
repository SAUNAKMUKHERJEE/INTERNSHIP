# %% [markdown]
# # Let's Importing the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import norm,skew
# %matplotlib inline

# %% [markdown]
# Github link is provided below, now we can extract data from Github

# %%
df1=pd.read_csv(r"C:\Users\91907\Music\train.csv")
df1
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3            Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 4            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1163         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1164         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1165         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1166         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1167         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0         2   2007        WD         Normal     128000
# 1        10   2007        WD         Normal     268000
# 2         6   2007        WD         Normal     269790
# 3         1   2010       COD         Normal     190000
# 4         6   2009        WD         Normal     215000
# ...     ...    ...       ...            ...        ...
# 1163      2   2010        WD         Normal     122000
# 1164      5   2009        WD         Normal     108000
# 1165      7   2009        WD         Normal     148500
# 1166      7   2008        WD         Normal      40000
# 1167      6   2006        WD         Normal     183200
#
# [1168 rows x 81 columns]

# %%
df2=pd.read_csv(r"C:\Users\91907\Music\test.csv")
df2
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0           HLS    AllPub  ...           0        0    NaN   NaN         NaN
# 1           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3           Bnk    AllPub  ...           0        0    NaN   NaN         NaN
# 4           Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# ..          ...       ...  ...         ...      ...    ...   ...         ...
# 287         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 288         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 289         Lvl    AllPub  ...           0        0    NaN   NaN        Shed
# 290         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 291         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      7    2007        WD         Normal
# 1         0      8    2009       COD        Abnorml
# 2         0      6    2009        WD         Normal
# 3         0      7    2009        WD         Normal
# 4         0      1    2008        WD         Normal
# ..      ...    ...     ...       ...            ...
# 287       0     10    2008        WD         Normal
# 288       0      2    2008        WD         Normal
# 289     700      3    2010        WD         Normal
# 290       0     10    2006        WD         Normal
# 291       0      6    2006        WD         Normal
#
# [292 rows x 80 columns]

# %% [markdown]
# # Describe:--->

# %%
df1.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1168.000000  1168.000000    954.00000    1168.000000  1168.000000
# mean    724.136130    56.767979     70.98847   10484.749144     6.104452
# std     416.159877    41.940650     24.82875    8957.442311     1.390153
# min       1.000000    20.000000     21.00000    1300.000000     1.000000
# 25%     360.500000    20.000000     60.00000    7621.500000     5.000000
# 50%     714.500000    50.000000     70.00000    9522.500000     6.000000
# 75%    1079.500000    70.000000     80.00000   11515.500000     7.000000
# max    1460.000000   190.000000    313.00000  164660.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1168.000000  1168.000000   1168.000000  1161.000000  1168.000000  ...
# mean      5.595890  1970.930651   1984.758562   102.310078   444.726027  ...
# std       1.124343    30.145255     20.785185   182.595606   462.664785  ...
# min       1.000000  1875.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1966.000000     0.000000     0.000000  ...
# 50%       5.000000  1972.000000   1993.000000     0.000000   385.500000  ...
# 75%       6.000000  2000.000000   2004.000000   160.000000   714.500000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1168.000000  1168.000000    1168.000000  1168.000000  1168.000000
# mean     96.206336    46.559932      23.015411     3.639555    15.051370
# std     126.158988    66.381023      63.191089    29.088867    55.080816
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    24.000000       0.000000     0.000000     0.000000
# 75%     171.000000    70.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1168.000000   1168.000000  1168.000000  1168.000000    1168.000000
# mean      3.448630     47.315068     6.344178  2007.804795  181477.005993
# std      44.896939    543.264432     2.686352     1.329738   79105.586863
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  130375.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163995.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  215000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
df2.describe()
# Out:
#                 Id  MSSubClass  LotFrontage        LotArea  OverallQual  \
# count   292.000000  292.000000   247.000000     292.000000   292.000000
# mean    755.955479   57.414384    66.425101   10645.143836     6.078767
# std     442.565228   43.780649    21.726343   13330.669795     1.356147
# min       6.000000   20.000000    21.000000    1526.000000     3.000000
# 25%     377.750000   20.000000    53.500000    7200.000000     5.000000
# 50%     778.000000   50.000000    65.000000    9200.000000     6.000000
# 75%    1152.250000   70.000000    79.000000   11658.750000     7.000000
# max    1456.000000  190.000000   150.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count   292.000000   292.000000    292.000000   291.000000   292.000000  ...
# mean      5.493151  1972.616438   1985.294521   109.171821   439.294521  ...
# std       1.063267    30.447016     20.105792   175.030021   429.559675  ...
# min       3.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1968.000000     0.000000     0.000000  ...
# 50%       5.000000  1976.000000   1994.000000     0.000000   369.500000  ...
# 75%       6.000000  2001.000000   2003.250000   180.000000   700.500000  ...
# max       9.000000  2009.000000   2010.000000  1031.000000  1767.000000  ...
#
#        WoodDeckSF  OpenPorchSF  EnclosedPorch   3SsnPorch  ScreenPorch  \
# count  292.000000   292.000000     292.000000  292.000000   292.000000
# mean    86.397260    47.061644      17.708904    2.489726    15.099315
# std    121.898836    65.865449      51.892906   30.247488    58.483473
# min      0.000000     0.000000       0.000000    0.000000     0.000000
# 25%      0.000000     0.000000       0.000000    0.000000     0.000000
# 50%      0.000000    28.500000       0.000000    0.000000     0.000000
# 75%    149.250000    66.000000       0.000000    0.000000     0.000000
# max    728.000000   418.000000     330.000000  407.000000   396.000000
#
#        PoolArea  PoolQC      MiscVal      MoSold       YrSold
# count     292.0     0.0   292.000000  292.000000   292.000000
# mean        0.0     NaN    28.184932    6.232877  2007.859589
# std         0.0     NaN   224.036218    2.774556     1.322867
# min         0.0     NaN     0.000000    1.000000  2006.000000
# 25%         0.0     NaN     0.000000    4.000000  2007.000000
# 50%         0.0     NaN     0.000000    6.000000  2008.000000
# 75%         0.0     NaN     0.000000    8.000000  2009.000000
# max         0.0     NaN  3500.000000   12.000000  2010.000000
#
# [8 rows x 38 columns]

# %%
print("Shape")
print("Training data : ", df1.shape)
print("Test data     : ", df2.shape)
# Out:
# Shape
# Training data :  (1168, 81)
# Test data     :  (292, 80)

# %% [markdown]
# # Checking null values:

# %%
df1.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df2.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %% [markdown]
# So many null values are present here

# %%
feast_counts=df1.nunique(dropna=False)

# %%
feast_counts.sort_values()
# Out:
# Utilities        1
# CentralAir       2
# Street           2
# HalfBath         3
# PavedDrive       3
#               ...
# 1stFlrSF       669
# BsmtUnfSF      681
# GrLivArea      746
# LotArea        892
# Id            1168
# Length: 81, dtype: int64

# %% [markdown]
# # EDA

# %%
sns.regplot(x="OverallQual",y="SalePrice",data=df1)
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
sns.set(style="darkgrid")
sns.scatterplot(x="GrLivArea",y="SalePrice",data=df1)
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
df1=df1.drop(df1[(df1['GrLivArea']>4000)&(df1['SalePrice']<300000)].index)

# %%
sns.set(style="darkgrid")
sns.scatterplot(x="GrLivArea",y="SalePrice",data=df1)
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %%
sns.set(style="darkgrid")
sns.scatterplot(x="YearBuilt",y="SalePrice",data=df1)
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
sns.distplot(df1['SalePrice'],fit=norm)
# Out:
# C:\Users\91907\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
mu,sigma=norm.fit(df1['SalePrice'])
stats.probplot(df1['SalePrice'],plot=plt)
# Out:
# ((array([-3.24160692, -2.97972935, -2.83380349, ...,  2.83380349,
#           2.97972935,  3.24160692]),
#   array([ 34900,  35311,  37900, ..., 625000, 745000, 755000], dtype=int64)),
#  (73817.95980740414, 181492.6183533448, 0.9305223256690061))

# %%
df1['SalePrice']=np.log1p(df1['SalePrice'])

# %%
stats.probplot(df1['SalePrice'],plot=plt)
# Out:
# ((array([-3.24160692, -2.97972935, -2.83380349, ...,  2.83380349,
#           2.97972935,  3.24160692]),
#   array([10.46027076, 10.47197813, 10.54273278, ..., 13.34550853,
#          13.52114084, 13.53447435])),
#  (0.3962564130602157, 12.028253232895475, 0.9942562419434414))

# %%
sns.distplot(df1['SalePrice'],fit=norm)
# Out:
# C:\Users\91907\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
df1.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
sns.scatterplot(y="SalePrice",x="LotArea",data=df1)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='SalePrice'>

# %%
train_ID=df1['Id']
test_ID=df2['Id']

# %%
df1.drop("Id",axis=1,inplace=True)
df2.drop("Id",axis=1,inplace=True)

# %%
n_train=df1.shape[0]
n_test=df2.shape[0]
y_train=df1.SalePrice.values
all_data=pd.concat((df1,df2)).reset_index(drop=True)
all_data.drop(['SalePrice'],axis=1,inplace=True)

# %%
all_data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
all_data_na=all_data.isnull().sum()/len(all_data)*100

# %%
all_data_na=all_data_na.drop(all_data_na[all_data_na==0].index).sort_values(ascending=False)

# %%
all_data_na
# Out:
# PoolQC          99.588477
# MiscFeature     96.296296
# Alley           93.758573
# Fence           80.727023
# FireplaceQu     47.325103
# LotFrontage     17.764060
# GarageType       5.555556
# GarageYrBlt      5.555556
# GarageFinish     5.555556
# GarageQual       5.555556
# GarageCond       5.555556
# BsmtExposure     2.606310
# BsmtFinType2     2.606310
# BsmtFinType1     2.537723
# BsmtCond         2.537723
# BsmtQual         2.537723
# MasVnrArea       0.548697
# MasVnrType       0.548697
# Electrical       0.068587
# dtype: float64

# %%
all_data_na.index
# Out:
# Index(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu', 'LotFrontage',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'BsmtCond', 'BsmtQual',
#        'MasVnrArea', 'MasVnrType', 'Electrical'],
#       dtype='object')

# %%
plt.subplots(figsize=(15,12))
plt.xticks(rotation=90)
sns.barplot(x=all_data_na.index,y=all_data_na)
# Out:
# <AxesSubplot:>

# %%
df1.corr()
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.387093 -0.127330     0.070569    -0.056921
# LotFrontage     -0.387093     1.000000  0.501342     0.227210    -0.049294
# LotArea         -0.127330     0.501342  1.000000     0.087232     0.022181
# OverallQual      0.070569     0.227210  0.087232     1.000000    -0.081186
# OverallCond     -0.056921    -0.049294  0.022181    -0.081186     1.000000
# YearBuilt        0.023858     0.109619 -0.004273     0.574572    -0.377195
# YearRemodAdd     0.056531     0.087209  0.018730     0.554911     0.081794
# MasVnrArea       0.027711     0.166983  0.094593     0.398621    -0.136123
# BsmtFinSF1      -0.056804     0.143056  0.166845     0.196770    -0.023385
# BsmtFinSF2      -0.062370     0.006350  0.060141    -0.039792     0.044090
# BsmtUnfSF       -0.134231     0.132404  0.005954     0.309745    -0.146245
# TotalBsmtSF     -0.230721     0.299080  0.205793     0.528636    -0.166452
# 1stFlrSF        -0.240080     0.384901  0.270324     0.448875    -0.134347
# 2ndFlrSF         0.301287     0.083434  0.046241     0.310144     0.038683
# LowQualFinSF     0.053754     0.010150 -0.000936    -0.038956     0.041774
# GrLivArea        0.089313     0.352620  0.239262     0.595624    -0.061352
# BsmtFullBath     0.004303     0.074534  0.126928     0.092859    -0.037983
# BsmtHalfBath     0.008239     0.004761  0.062412    -0.029773     0.090828
# FullBath         0.141032     0.185528  0.114408     0.546073    -0.170971
# HalfBath         0.168476     0.039640 -0.002411     0.292655    -0.051101
# BedroomAbvGr    -0.013302     0.277195  0.118618     0.099634     0.028529
# KitchenAbvGr     0.283546    -0.000118 -0.011641    -0.178424    -0.076260
# TotRmsAbvGrd     0.051198     0.331392  0.163809     0.424055    -0.037453
# Fireplaces      -0.036289     0.235878  0.272652     0.384706    -0.011771
# GarageYrBlt      0.077511     0.048686 -0.045664     0.540280    -0.317581
# GarageCars      -0.027800     0.285801  0.155434     0.596395    -0.161345
# GarageArea      -0.093748     0.317593  0.172464     0.560946    -0.124418
# WoodDeckSF      -0.022746     0.094314  0.213886     0.224436     0.013130
# OpenPorchSF      0.017185     0.125177  0.061139     0.327382    -0.021153
# EnclosedPorch   -0.004205     0.029435 -0.004643    -0.097291     0.055762
# 3SsnPorch       -0.043195     0.064478  0.027341     0.046838     0.040372
# ScreenPorch     -0.013256     0.038657  0.027995     0.061119     0.069236
# PoolArea         0.009349     0.126261  0.046201     0.049682     0.001253
# MiscVal         -0.023492    -0.002924  0.053448    -0.025540     0.075118
# MoSold          -0.016014     0.044678  0.021950     0.093009     0.005247
# YrSold          -0.038571    -0.004632 -0.035145    -0.047989     0.055330
# SalePrice       -0.045993     0.360940  0.255614     0.823827    -0.018367
#
#                YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# MSSubClass      0.023858      0.056531    0.027711   -0.056804   -0.062370
# LotFrontage     0.109619      0.087209    0.166983    0.143056    0.006350
# LotArea        -0.004273      0.018730    0.094593    0.166845    0.060141
# OverallQual     0.574572      0.554911    0.398621    0.196770   -0.039792
# OverallCond    -0.377195      0.081794   -0.136123   -0.023385    0.044090
# YearBuilt       1.000000      0.591884    0.319420    0.226526   -0.027124
# YearRemodAdd    0.591884      1.000000    0.176988    0.106681   -0.044197
# MasVnrArea      0.319420      0.176988    1.000000    0.235408   -0.064668
# BsmtFinSF1      0.226526      0.106681    0.235408    1.000000   -0.051680
# BsmtFinSF2     -0.027124     -0.044197   -0.064668   -0.051680    1.000000
# BsmtUnfSF       0.155329      0.174521    0.109797   -0.533545   -0.213531
# TotalBsmtSF     0.396705      0.284814    0.341793    0.449798    0.109531
# 1stFlrSF        0.278115      0.230946    0.312887    0.382902    0.101637
# 2ndFlrSF        0.007653      0.151957    0.163009   -0.160636   -0.091419
# LowQualFinSF   -0.189025     -0.072364   -0.070557   -0.073942   -0.000639
# GrLivArea       0.192662      0.294590    0.363292    0.135764   -0.004295
# BsmtFullBath    0.161587      0.101247    0.074578    0.656222    0.165272
# BsmtHalfBath   -0.027707     -0.010936    0.015898    0.071441    0.093587
# FullBath        0.469841      0.443070    0.261729    0.040762   -0.060137
# HalfBath        0.241314      0.193070    0.195731    0.000012   -0.023172
# BedroomAbvGr   -0.081038     -0.036158    0.091910   -0.124547   -0.005719
# KitchenAbvGr   -0.167650     -0.139695   -0.037397   -0.066922   -0.034518
# TotRmsAbvGrd    0.089874      0.202884    0.264858    0.001270   -0.032458
# Fireplaces      0.130781      0.115103    0.234096    0.236332    0.049281
# GarageYrBlt     0.825923      0.638307    0.250051    0.127867   -0.071163
# GarageCars      0.524634      0.427431    0.340916    0.202007   -0.020356
# GarageArea      0.471877      0.385925    0.353216    0.256012   -0.000517
# WoodDeckSF      0.203336      0.196013    0.148032    0.193202    0.095210
# OpenPorchSF     0.185286      0.234625    0.105913    0.059677   -0.012098
# EnclosedPorch  -0.373300     -0.193104   -0.101211   -0.082817    0.031908
# 3SsnPorch       0.037387      0.065074    0.019760    0.028929   -0.031326
# ScreenPorch    -0.058269     -0.045747    0.048850    0.039529    0.076437
# PoolArea       -0.004969     -0.003412   -0.022239    0.059158    0.051105
# MiscVal        -0.029865     -0.001033   -0.027350    0.010080    0.007873
# MoSold          0.032578      0.025356    0.015940    0.023607   -0.014797
# YrSold         -0.013529      0.033747   -0.012232    0.006659    0.038334
# SalePrice       0.576381      0.570759    0.423796    0.372575    0.014543
#
#                ...  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# MSSubClass     ...   -0.022746     0.017185      -0.004205  -0.043195
# LotFrontage    ...    0.094314     0.125177       0.029435   0.064478
# LotArea        ...    0.213886     0.061139      -0.004643   0.027341
# OverallQual    ...    0.224436     0.327382      -0.097291   0.046838
# OverallCond    ...    0.013130    -0.021153       0.055762   0.040372
# YearBuilt      ...    0.203336     0.185286      -0.373300   0.037387
# YearRemodAdd   ...    0.196013     0.234625      -0.193104   0.065074
# MasVnrArea     ...    0.148032     0.105913      -0.101211   0.019760
# BsmtFinSF1     ...    0.193202     0.059677      -0.082817   0.028929
# BsmtFinSF2     ...    0.095210    -0.012098       0.031908  -0.031326
# BsmtUnfSF      ...   -0.002305     0.138614      -0.013113   0.025834
# TotalBsmtSF    ...    0.238418     0.208989      -0.088727   0.046149
# 1stFlrSF       ...    0.235598     0.170111      -0.045544   0.073278
# 2ndFlrSF       ...    0.082895     0.240048       0.066593  -0.025892
# LowQualFinSF   ...   -0.033381     0.027076       0.073621  -0.004057
# GrLivArea      ...    0.242136     0.336031       0.031499   0.031198
# BsmtFullBath   ...    0.159335     0.047232      -0.037218  -0.000342
# BsmtHalfBath   ...    0.051444    -0.049610       0.000770   0.050783
# FullBath       ...    0.175026     0.269952      -0.094022   0.045765
# HalfBath       ...    0.099965     0.221329      -0.088365  -0.009866
# BedroomAbvGr   ...    0.037805     0.099916       0.062903  -0.013944
# KitchenAbvGr   ...   -0.084773    -0.071349       0.030167  -0.026318
# TotRmsAbvGrd   ...    0.150380     0.247652       0.020755  -0.004559
# Fireplaces     ...    0.174846     0.163312      -0.022026   0.015531
# GarageYrBlt    ...    0.218855     0.231609      -0.277832   0.032894
# GarageCars     ...    0.212168     0.215109      -0.130538   0.037154
# GarageArea     ...    0.213264     0.238685      -0.098976   0.036779
# WoodDeckSF     ...    1.000000     0.050177      -0.124969  -0.029788
# OpenPorchSF    ...    0.050177     1.000000      -0.085874   0.004701
# EnclosedPorch  ...   -0.124969    -0.085874       1.000000  -0.040211
# 3SsnPorch      ...   -0.029788     0.004701      -0.040211   1.000000
# ScreenPorch    ...   -0.079139     0.069638      -0.082381  -0.034280
# PoolArea       ...    0.075720     0.037120       0.063825  -0.008930
# MiscVal        ...   -0.006729    -0.017715       0.021323  -0.010925
# MoSold         ...    0.009845     0.070281      -0.036815   0.020390
# YrSold         ...    0.031345    -0.064602      -0.005912   0.014393
# SalePrice      ...    0.327570     0.342731      -0.133158   0.069454
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# MSSubClass       -0.013256  0.009349 -0.023492 -0.016014 -0.038571  -0.045993
# LotFrontage       0.038657  0.126261 -0.002924  0.044678 -0.004632   0.360940
# LotArea           0.027995  0.046201  0.053448  0.021950 -0.035145   0.255614
# OverallQual       0.061119  0.049682 -0.025540  0.093009 -0.047989   0.823827
# OverallCond       0.069236  0.001253  0.075118  0.005247  0.055330  -0.018367
# YearBuilt        -0.058269 -0.004969 -0.029865  0.032578 -0.013529   0.576381
# YearRemodAdd     -0.045747 -0.003412 -0.001033  0.025356  0.033747   0.570759
# MasVnrArea        0.048850 -0.022239 -0.027350  0.015940 -0.012232   0.423796
# BsmtFinSF1        0.039529  0.059158  0.010080  0.023607  0.006659   0.372575
# BsmtFinSF2        0.076437  0.051105  0.007873 -0.014797  0.038334   0.014543
# BsmtUnfSF         0.001183 -0.038820 -0.017236  0.028896 -0.049368   0.218756
# TotalBsmtSF       0.073169  0.040180 -0.005057  0.050442 -0.031586   0.635923
# 1stFlrSF          0.077094  0.068796 -0.010220  0.058346 -0.028457   0.605877
# 2ndFlrSF          0.049014  0.082285  0.015694  0.040426 -0.037162   0.330279
# LowQualFinSF      0.037347  0.070245 -0.003583 -0.029335 -0.035007  -0.050743
# GrLivArea         0.103047  0.129052  0.005695  0.075076 -0.056687   0.727633
# BsmtFullBath      0.014886  0.050533 -0.024493 -0.009076  0.061030   0.227469
# BsmtHalfBath      0.008741  0.026658 -0.007869  0.039903 -0.052680  -0.003448
# FullBath         -0.003238  0.051393 -0.013238  0.065662 -0.035941   0.594641
# HalfBath          0.065748  0.013802  0.005339 -0.000776 -0.015341   0.319598
# BedroomAbvGr      0.051106  0.079953  0.015025  0.064823 -0.036502   0.199963
# KitchenAbvGr     -0.050360 -0.014973  0.045857  0.023186 -0.007992  -0.141035
# TotRmsAbvGrd      0.060854  0.067020  0.031061  0.061667 -0.060468   0.536246
# Fireplaces        0.191436  0.075770  0.010724  0.071294 -0.025326   0.484863
# GarageYrBlt      -0.085683 -0.027633 -0.035076  0.004192 -0.010973   0.528870
# GarageCars        0.039053  0.020932 -0.035675  0.079682 -0.057130   0.672101
# GarageArea        0.035780  0.028542 -0.018383  0.063056 -0.036971   0.653697
# WoodDeckSF       -0.079139  0.075720 -0.006729  0.009845  0.031345   0.327570
# OpenPorchSF       0.069638  0.037120 -0.017715  0.070281 -0.064602   0.342731
# EnclosedPorch    -0.082381  0.063825  0.021323 -0.036815 -0.005912  -0.133158
# 3SsnPorch        -0.034280 -0.008930 -0.010925  0.020390  0.014393   0.069454
# ScreenPorch       1.000000  0.063755  0.040448  0.033001  0.017208   0.112049
# PoolArea          0.063755  1.000000  0.032152 -0.021554 -0.070962   0.082827
# MiscVal           0.040448  0.032152  1.000000 -0.008842 -0.008474  -0.005966
# MoSold            0.033001 -0.021554 -0.008842  1.000000 -0.143963   0.087126
# YrSold            0.017208 -0.070962 -0.008474 -0.143963  1.000000  -0.048505
# SalePrice         0.112049  0.082827 -0.005966  0.087126 -0.048505   1.000000
#
# [37 rows x 37 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(35,15))
sns.heatmap(df1.corr(),annot=True,linewidths=0.5,linecolor="black",fmt='2f')
# Out:
# <AxesSubplot:>

# %%
all_data['PoolQC']=all_data['PoolQC'].fillna("None")

# %%
all_data['MiscFeature']=all_data['MiscFeature'].fillna("None")

# %%
all_data['Alley']=all_data['Alley'].fillna("None")

# %%
all_data['Fence']=all_data['Fence'].fillna("None")

# %%
all_data['FireplaceQu']=all_data['FireplaceQu'].fillna("None")

# %%
all_data['LotFrontage']=all_data.groupby('Neighborhood')['LotFrontage'].transform(lambda x:x.fillna(x.median()))

# %%
for cols in ('GarageCond','GarageFinish', 'GarageQual', 'GarageType'):
    all_data[cols]=all_data[cols].fillna('None')

# %%
for cols in('GarageArea', 'GarageCars','GarageYrBlt'):
    all_data[cols]=all_data[cols].fillna(0)

# %%
for cols in ('BsmtCond', 'BsmtQual', 'BsmtFinType2', 'BsmtFinType1','BsmtExposure'):
    all_data[cols]=all_data[cols].fillna('None')

# %%
for cols in ('BsmtFinSF1', 'BsmtFinSF2','BsmtFullBath', 'BsmtHalfBath','BsmtUnfSF','TotalBsmtSF'):
    all_data[cols]=all_data[cols].fillna(0)

# %%
all_data['MasVnrType']=all_data['MasVnrType'].fillna('None')
all_data['MasVnrArea']=all_data['MasVnrArea'].fillna(0)

# %%
all_data['MSZoning'].value_counts()
# Out:
# RL         1149
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
all_data['MSZoning']=all_data['MSZoning'].fillna('RL')

# %%
all_data['Utilities'].value_counts()
# Out:
# AllPub    1457
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
all_data_=all_data.drop(['Utilities'],axis=1)

# %%
all_data['Functional']=all_data['Functional'].fillna('Typ')

# %%
all_data['Electrical']=all_data['Electrical'].fillna('SBrkr')

# %%
all_data['Exterior1st']=all_data['Exterior1st'].fillna('VinylSd')

# %%
all_data['Exterior2nd']=all_data['Exterior2nd'].fillna('VinylSd')

# %%
all_data['KitchenQual']=all_data['KitchenQual'].fillna('TA')

# %%
all_data['SaleType']=all_data['SaleType'].fillna('WD')

# %%
all_data_na=all_data.isnull().sum()/len(all_data)*100
all_data_na=all_data_na.drop(all_data_na[all_data_na==0].index).sort_values(ascending=False)
all_data_na
# Out:
# Series([], dtype: float64)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1458 non-null   int64
#  1   MSZoning       1458 non-null   object
#  2   LotFrontage    1458 non-null   float64
#  3   LotArea        1458 non-null   int64
#  4   Street         1458 non-null   object
#  5   Alley          1458 non-null   object
#  6   LotShape       1458 non-null   object
#  7   LandContour    1458 non-null   object
#  8   Utilities      1458 non-null   object
#  9   LotConfig      1458 non-null   object
#  10  LandSlope      1458 non-null   object
#  11  Neighborhood   1458 non-null   object
#  12  Condition1     1458 non-null   object
#  13  Condition2     1458 non-null   object
#  14  BldgType       1458 non-null   object
#  15  HouseStyle     1458 non-null   object
#  16  OverallQual    1458 non-null   int64
#  17  OverallCond    1458 non-null   int64
#  18  YearBuilt      1458 non-null   int64
#  19  YearRemodAdd   1458 non-null   int64
#  20  RoofStyle      1458 non-null   object
#  21  RoofMatl       1458 non-null   object
#  22  Exterior1st    1458 non-null   object
#  23  Exterior2nd    1458 non-null   object
#  24  MasVnrType     1458 non-null   object
#  25  MasVnrArea     1458 non-null   float64
#  26  ExterQual      1458 non-null   object
#  27  ExterCond      1458 non-null   object
#  28  Foundation     1458 non-null   object
#  29  BsmtQual       1458 non-null   object
#  30  BsmtCond       1458 non-null   object
#  31  BsmtExposure   1458 non-null   object
#  32  BsmtFinType1   1458 non-null   object
#  33  BsmtFinSF1     1458 non-null   int64
#  34  BsmtFinType2   1458 non-null   object
#  35  BsmtFinSF2     1458 non-null   int64
#  36  BsmtUnfSF      1458 non-null   int64
#  37  TotalBsmtSF    1458 non-null   int64
#  38  Heating        1458 non-null   object
#  39  HeatingQC      1458 non-null   object
#  40  CentralAir     1458 non-null   object
#  41  Electrical     1458 non-null   object
#  42  1stFlrSF       1458 non-null   int64
#  43  2ndFlrSF       1458 non-null   int64
#  44  LowQualFinSF   1458 non-null   int64
#  45  GrLivArea      1458 non-null   int64
#  46  BsmtFullBath   1458 non-null   int64
#  47  BsmtHalfBath   1458 non-null   int64
#  48  FullBath       1458 non-null   int64
#  49  HalfBath       1458 non-null   int64
#  50  BedroomAbvGr   1458 non-null   int64
#  51  KitchenAbvGr   1458 non-null   int64
#  52  KitchenQual    1458 non-null   object
#  53  TotRmsAbvGrd   1458 non-null   int64
#  54  Functional     1458 non-null   object
#  55  Fireplaces     1458 non-null   int64
#  56  FireplaceQu    1458 non-null   object
#  57  GarageType     1458 non-null   object
#  58  GarageYrBlt    1458 non-null   float64
#  59  GarageFinish   1458 non-null   object
#  60  GarageCars     1458 non-null   int64
#  61  GarageArea     1458 non-null   int64
#  62  GarageQual     1458 non-null   object
#  63  GarageCond     1458 non-null   object
#  64  PavedDrive     1458 non-null   object
#  65  WoodDeckSF     1458 non-null   int64
#  66  OpenPorchSF    1458 non-null   int64
#  67  EnclosedPorch  1458 non-null   int64
#  68  3SsnPorch      1458 non-null   int64
#  69  ScreenPorch    1458 non-null   int64
#  70  PoolArea       1458 non-null   int64
#  71  PoolQC         1458 non-null   object
#  72  Fence          1458 non-null   object
#  73  MiscFeature    1458 non-null   object
#  74  MiscVal        1458 non-null   int64
#  75  MoSold         1458 non-null   int64
#  76  YrSold         1458 non-null   int64
#  77  SaleType       1458 non-null   object
#  78  SaleCondition  1458 non-null   object
# dtypes: float64(3), int64(33), object(43)
# memory usage: 900.0+ KB

# %%
all_data['MSSubClass'] = all_data['MSSubClass'].apply(str)
all_data['OverallCond'] = all_data['OverallCond'].astype(str)
all_data['YrSold'] = all_data['YrSold'].astype(str)
all_data['MoSold'] = all_data['MoSold'].astype(str)

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')
for c in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(all_data[c].values)) 
    all_data[c] = lbl.transform(list(all_data[c].values))

# %%
all_data.shape
# Out:
# (1458, 79)

# %%
all_data['TotalSF']=all_data['TotalBsmtSF']+all_data['1stFlrSF']+all_data['2ndFlrSF']

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1458 non-null   int32
#  1   MSZoning       1458 non-null   object
#  2   LotFrontage    1458 non-null   float64
#  3   LotArea        1458 non-null   int64
#  4   Street         1458 non-null   int32
#  5   Alley          1458 non-null   int32
#  6   LotShape       1458 non-null   int32
#  7   LandContour    1458 non-null   object
#  8   Utilities      1458 non-null   object
#  9   LotConfig      1458 non-null   object
#  10  LandSlope      1458 non-null   int32
#  11  Neighborhood   1458 non-null   object
#  12  Condition1     1458 non-null   object
#  13  Condition2     1458 non-null   object
#  14  BldgType       1458 non-null   object
#  15  HouseStyle     1458 non-null   object
#  16  OverallQual    1458 non-null   int64
#  17  OverallCond    1458 non-null   int32
#  18  YearBuilt      1458 non-null   int64
#  19  YearRemodAdd   1458 non-null   int64
#  20  RoofStyle      1458 non-null   object
#  21  RoofMatl       1458 non-null   object
#  22  Exterior1st    1458 non-null   object
#  23  Exterior2nd    1458 non-null   object
#  24  MasVnrType     1458 non-null   object
#  25  MasVnrArea     1458 non-null   float64
#  26  ExterQual      1458 non-null   int32
#  27  ExterCond      1458 non-null   int32
#  28  Foundation     1458 non-null   object
#  29  BsmtQual       1458 non-null   int32
#  30  BsmtCond       1458 non-null   int32
#  31  BsmtExposure   1458 non-null   int32
#  32  BsmtFinType1   1458 non-null   int32
#  33  BsmtFinSF1     1458 non-null   int64
#  34  BsmtFinType2   1458 non-null   int32
#  35  BsmtFinSF2     1458 non-null   int64
#  36  BsmtUnfSF      1458 non-null   int64
#  37  TotalBsmtSF    1458 non-null   int64
#  38  Heating        1458 non-null   object
#  39  HeatingQC      1458 non-null   int32
#  40  CentralAir     1458 non-null   int32
#  41  Electrical     1458 non-null   object
#  42  1stFlrSF       1458 non-null   int64
#  43  2ndFlrSF       1458 non-null   int64
#  44  LowQualFinSF   1458 non-null   int64
#  45  GrLivArea      1458 non-null   int64
#  46  BsmtFullBath   1458 non-null   int64
#  47  BsmtHalfBath   1458 non-null   int64
#  48  FullBath       1458 non-null   int64
#  49  HalfBath       1458 non-null   int64
#  50  BedroomAbvGr   1458 non-null   int64
#  51  KitchenAbvGr   1458 non-null   int64
#  52  KitchenQual    1458 non-null   int32
#  53  TotRmsAbvGrd   1458 non-null   int64
#  54  Functional     1458 non-null   int32
#  55  Fireplaces     1458 non-null   int64
#  56  FireplaceQu    1458 non-null   int32
#  57  GarageType     1458 non-null   object
#  58  GarageYrBlt    1458 non-null   float64
#  59  GarageFinish   1458 non-null   int32
#  60  GarageCars     1458 non-null   int64
#  61  GarageArea     1458 non-null   int64
#  62  GarageQual     1458 non-null   int32
#  63  GarageCond     1458 non-null   int32
#  64  PavedDrive     1458 non-null   int32
#  65  WoodDeckSF     1458 non-null   int64
#  66  OpenPorchSF    1458 non-null   int64
#  67  EnclosedPorch  1458 non-null   int64
#  68  3SsnPorch      1458 non-null   int64
#  69  ScreenPorch    1458 non-null   int64
#  70  PoolArea       1458 non-null   int64
#  71  PoolQC         1458 non-null   int32
#  72  Fence          1458 non-null   int32
#  73  MiscFeature    1458 non-null   object
#  74  MiscVal        1458 non-null   int64
#  75  MoSold         1458 non-null   int32
#  76  YrSold         1458 non-null   int32
#  77  SaleType       1458 non-null   object
#  78  SaleCondition  1458 non-null   object
#  79  TotalSF        1458 non-null   int64
# dtypes: float64(3), int32(26), int64(30), object(21)
# memory usage: 763.3+ KB

# %%
numeric_feats=all_data.dtypes[all_data.dtypes!='object'].index
numeric_feats
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'Street', 'Alley', 'LotShape',
#        'LandSlope', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'HeatingQC', 'CentralAir',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
#        'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'PoolQC', 'Fence', 'MiscVal', 'MoSold', 'YrSold', 'TotalSF'],
#       dtype='object')

# %% [markdown]
# # Skewness

# %%
skewed_feats=all_data[numeric_feats].apply(lambda x:skew(x.dropna())).sort_values(ascending=False)

# %%
skewness=pd.DataFrame({'Skew':skewed_feats})

# %%
print(skewness.shape)
skewness
# Out:
# (59, 1)
#                     Skew
# MiscVal        24.434913
# PoolArea       15.932532
# LotArea        12.560986
# 3SsnPorch      10.286510
# LowQualFinSF    8.995688
# LandSlope       4.805032
# KitchenAbvGr    4.480268
# BsmtFinSF2      4.247550
# ScreenPorch     4.114690
# BsmtHalfBath    4.095895
# EnclosedPorch   3.083987
# MasVnrArea      2.693554
# OpenPorchSF     2.337421
# LotFrontage     1.546624
# WoodDeckSF      1.544214
# GrLivArea       1.009951
# BsmtUnfSF       0.919955
# 1stFlrSF        0.886723
# 2ndFlrSF        0.812121
# TotalSF         0.803494
# BsmtFinSF1      0.764002
# OverallCond     0.690324
# HalfBath        0.679351
# TotRmsAbvGrd    0.659822
# Fireplaces      0.631409
# BsmtFullBath    0.589751
# TotalBsmtSF     0.511177
# HeatingQC       0.480478
# FireplaceQu     0.302607
# MSSubClass      0.261945
# BedroomAbvGr    0.212107
# OverallQual     0.200579
# GarageArea      0.131612
# BsmtFinType1    0.108344
# YrSold          0.095322
# FullBath        0.031239
# Alley          -0.322076
# GarageCars     -0.342025
# BsmtQual       -0.496713
# YearRemodAdd   -0.501322
# LotShape       -0.611279
# YearBuilt      -0.611665
# GarageFinish   -0.620936
# MoSold         -0.674910
# BsmtExposure   -1.101682
# KitchenQual    -1.424394
# ExterQual      -1.824837
# Fence          -2.039560
# ExterCond      -2.560180
# BsmtCond       -2.936326
# BsmtFinType2   -3.170749
# GarageQual     -3.245764
# PavedDrive     -3.302685
# CentralAir     -3.523786
# GarageCond     -3.577060
# GarageYrBlt    -3.862401
# Functional     -4.077484
# Street        -15.492067
# PoolQC        -18.475479

# %%
skewness=skewness[abs(skewness)>0.75]
print(skewness.shape)
# Out:
# (59, 1)

# %%
from scipy.special import boxcox1p
skewed_features=skewness.index
lam=0.15
for feat in skewed_features:
    all_data[feat]=boxcox1p(all_data[feat],lam)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1458 non-null   float64
#  1   MSZoning       1458 non-null   object
#  2   LotFrontage    1458 non-null   float64
#  3   LotArea        1458 non-null   float64
#  4   Street         1458 non-null   float64
#  5   Alley          1458 non-null   float64
#  6   LotShape       1458 non-null   float64
#  7   LandContour    1458 non-null   object
#  8   Utilities      1458 non-null   object
#  9   LotConfig      1458 non-null   object
#  10  LandSlope      1458 non-null   float64
#  11  Neighborhood   1458 non-null   object
#  12  Condition1     1458 non-null   object
#  13  Condition2     1458 non-null   object
#  14  BldgType       1458 non-null   object
#  15  HouseStyle     1458 non-null   object
#  16  OverallQual    1458 non-null   float64
#  17  OverallCond    1458 non-null   float64
#  18  YearBuilt      1458 non-null   float64
#  19  YearRemodAdd   1458 non-null   float64
#  20  RoofStyle      1458 non-null   object
#  21  RoofMatl       1458 non-null   object
#  22  Exterior1st    1458 non-null   object
#  23  Exterior2nd    1458 non-null   object
#  24  MasVnrType     1458 non-null   object
#  25  MasVnrArea     1458 non-null   float64
#  26  ExterQual      1458 non-null   float64
#  27  ExterCond      1458 non-null   float64
#  28  Foundation     1458 non-null   object
#  29  BsmtQual       1458 non-null   float64
#  30  BsmtCond       1458 non-null   float64
#  31  BsmtExposure   1458 non-null   float64
#  32  BsmtFinType1   1458 non-null   float64
#  33  BsmtFinSF1     1458 non-null   float64
#  34  BsmtFinType2   1458 non-null   float64
#  35  BsmtFinSF2     1458 non-null   float64
#  36  BsmtUnfSF      1458 non-null   float64
#  37  TotalBsmtSF    1458 non-null   float64
#  38  Heating        1458 non-null   object
#  39  HeatingQC      1458 non-null   float64
#  40  CentralAir     1458 non-null   float64
#  41  Electrical     1458 non-null   object
#  42  1stFlrSF       1458 non-null   float64
#  43  2ndFlrSF       1458 non-null   float64
#  44  LowQualFinSF   1458 non-null   float64
#  45  GrLivArea      1458 non-null   float64
#  46  BsmtFullBath   1458 non-null   float64
#  47  BsmtHalfBath   1458 non-null   float64
#  48  FullBath       1458 non-null   float64
#  49  HalfBath       1458 non-null   float64
#  50  BedroomAbvGr   1458 non-null   float64
#  51  KitchenAbvGr   1458 non-null   float64
#  52  KitchenQual    1458 non-null   float64
#  53  TotRmsAbvGrd   1458 non-null   float64
#  54  Functional     1458 non-null   float64
#  55  Fireplaces     1458 non-null   float64
#  56  FireplaceQu    1458 non-null   float64
#  57  GarageType     1458 non-null   object
#  58  GarageYrBlt    1458 non-null   float64
#  59  GarageFinish   1458 non-null   float64
#  60  GarageCars     1458 non-null   float64
#  61  GarageArea     1458 non-null   float64
#  62  GarageQual     1458 non-null   float64
#  63  GarageCond     1458 non-null   float64
#  64  PavedDrive     1458 non-null   float64
#  65  WoodDeckSF     1458 non-null   float64
#  66  OpenPorchSF    1458 non-null   float64
#  67  EnclosedPorch  1458 non-null   float64
#  68  3SsnPorch      1458 non-null   float64
#  69  ScreenPorch    1458 non-null   float64
#  70  PoolArea       1458 non-null   float64
#  71  PoolQC         1458 non-null   float64
#  72  Fence          1458 non-null   float64
#  73  MiscFeature    1458 non-null   object
#  74  MiscVal        1458 non-null   float64
#  75  MoSold         1458 non-null   float64
#  76  YrSold         1458 non-null   float64
#  77  SaleType       1458 non-null   object
#  78  SaleCondition  1458 non-null   object
#  79  TotalSF        1458 non-null   float64
# dtypes: float64(59), object(21)
# memory usage: 911.4+ KB

# %%
all_data=pd.get_dummies(all_data)
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Columns: 222 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(59), uint8(163)
# memory usage: 904.3 KB

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Columns: 222 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(59), uint8(163)
# memory usage: 904.3 KB

# %%
train=all_data[:n_train]
test=all_data[n_train:]

# %%
train.shape
# Out:
# (1166, 222)

# %%
test.shape
# Out:
# (292, 222)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\91907\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: scipy in c:\users\91907\anaconda3\lib\site-packages (from xgboost) (1.7.1)
# Requirement already satisfied: numpy in c:\users\91907\anaconda3\lib\site-packages (from xgboost) (1.20.3)

# %%
# !pip install lightgbm
# Out:
# Requirement already satisfied: lightgbm in c:\users\91907\anaconda3\lib\site-packages (3.3.2)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\91907\anaconda3\lib\site-packages (from lightgbm) (0.24.2)
# Requirement already satisfied: scipy in c:\users\91907\anaconda3\lib\site-packages (from lightgbm) (1.7.1)
# Requirement already satisfied: wheel in c:\users\91907\anaconda3\lib\site-packages (from lightgbm) (0.37.0)
# Requirement already satisfied: numpy in c:\users\91907\anaconda3\lib\site-packages (from lightgbm) (1.20.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\91907\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\91907\anaconda3\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.1.0)

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %%
n_folds=5
def rmsle_cv(model):
    kf=KFold(n_folds,shuffle=True,random_state=42).get_n_splits(train.values)
    rmse=np.sqrt(-cross_val_score(model,train.values,y_train,scoring="neg_mean_squared_error",cv=kf))
    return (rmse)

# %%
lasso=make_pipeline(RobustScaler(),Lasso(alpha=0.0005,random_state=1))

# %%
Enet=make_pipeline(RobustScaler(),ElasticNet(alpha=0.005,l1_ratio=0.9,random_state=3))

# %%
KRR=KernelRidge(alpha=0.6,kernel='polynomial',degree=2,coef0=2.5)

# %%
GBoost=GradientBoostingRegressor(loss='huber',n_estimators=3000,learning_rate=0.05,max_depth=4,max_features='sqrt',min_samples_leaf=15,
                                min_samples_split=10,random_state=5)

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %%
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %%
score=rmsle_cv(lasso)
print(score.mean())
print(score.std())
# Out:
# 0.11701087239637946
# 0.011008360946233099

# %%
score=rmsle_cv(Enet)
print(score.mean())
print(score.std())
# Out:
# 0.12777438890229376
# 0.012957905527222877

# %%
score=rmsle_cv(KRR)
print(score.mean())
print(score.std())
# Out:
# 0.12065866863476189
# 0.011203035012687535

# %%
score=rmsle_cv(GBoost)
print(score.mean())
print(score.std())
# Out:
# 0.12262031540798723
# 0.01635298335448197

# %%
score=rmsle_cv(model_xgb)
print(score.mean())
print(score.std())
# Out:
# [22:24:56] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:24:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:24:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:25:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:25:01] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# 0.1224760949753799
# 0.011957018213140777

# %%
score=rmsle_cv(model_lgb)
print(score.mean())
print(score.std())
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# 0.12267847762389061
# 0.015838078203920868

# %%
class AveragingModels(BaseEstimator,RegressorMixin,TransformerMixin):
    def __init__(self,models):
        self.models=models;
    
    def fit(self,X,y):
        self.models_=[clone(x) for x in self.models]
        for model in self.models_:
            model.fit(X,y)
        return self
    
    def predict(self,X):
        predictions=np.column_stack([model.predict(X) for model in self.models_])
        return np.mean(predictions,axis=1)

# %%
avg_models=AveragingModels(models=(Enet,GBoost,KRR,lasso))
score=rmsle_cv(avg_models)
print(score.mean())
print(score.std())
# Out:
# 0.11464853430435262
# 0.014497440442183927

# %%
avg_models=AveragingModels(models=(model_xgb,GBoost,KRR,lasso))
score=rmsle_cv(avg_models)
print(score.mean())
print(score.std())
# Out:
# [22:25:45] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:25:54] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:26:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:26:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [22:26:23] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# 0.11409315995156197
# 0.014166649754835604

# %%
avg_models=AveragingModels(models=(model_xgb,model_lgb,KRR,lasso))
score=rmsle_cv(avg_models)
print(score.mean())
print(score.std())
# Out:
# [22:26:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [22:26:34] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [22:26:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [22:26:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [22:26:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# 0.11461959382210955
# 0.013794248476832435

# %%
avg_models=AveragingModels(models=(Enet,GBoost,KRR,lasso,model_xgb,model_lgb))
score=rmsle_cv(avg_models)
print(score.mean())
print(score.std())
# Out:
# [22:26:50] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [22:27:00] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [22:27:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [22:27:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# [22:27:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# 0.11457420127440403
# 0.014831696199282372

# %%
class StackingAverageModels(BaseEstimator,RegressorMixin,TransformerMixin):
    def __init__(self,base_models,meta_model,n_folds=5):
        self.base_models=base_models
        self.meta_model=meta_model
        self.n_folds=n_folds
    
    def fit(self,X,y):
        self.base_models_=[list() for x in self.base_models]
        self.meta_model_=clone(self.meta_model)
        kfold=KFold(n_splits=self.n_folds,shuffle=True,random_state=156)
        
        out_of_fold_pred=np.zeros((X.shape[0],len(self.base_models)))
        for i,model in enumerate(self.base_models):
            for train_index,holdout_index in kfold.split(X,y):
                instance=clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index],y[train_index])
                out_of_fold_pred[holdout_index,i]=instance.predict(X[holdout_index])
        
        self.meta_model_.fit(out_of_fold_pred,y)
        return self
    
    def predict(self,X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)
stacked_averaged_models = StackingAverageModels(base_models = (Enet, GBoost, KRR),
                                                 meta_model = lasso)

# %%
stacked_averaged_models = StackingAverageModels(base_models = (Enet, GBoost, KRR),
                                                 meta_model = lasso)

score = rmsle_cv(stacked_averaged_models)
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 0.1150 (0.0140)

# %%
def rmsle(y,y_pred):
    return np.sqrt(mean_squared_error(y,y_pred))

# %%
stacked_averaged_models.fit(train.values,y_train)
stacked_train_pred=stacked_averaged_models.predict(train.values)
stacked_predict=np.expm1(stacked_averaged_models.predict(test.values))
print(rmsle(y_train,stacked_train_pred))
# Out:
# 0.07635006440414409

# %%
model_lgb.fit(train.values,y_train)
lgb_train_pred=model_lgb.predict(train.values)
lgb_predict=np.expm1(model_lgb.predict(test.values))
print(rmsle(y_train,lgb_train_pred))
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.2319, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.2319
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] min_sum_hessian_in_leaf is set=11, min_child_weight=0.001 will be ignored. Current value: min_sum_hessian_in_leaf=11
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# 0.06807529688607969

# %%
model_xgb.fit(train, y_train)
xgb_train_pred = model_xgb.predict(train)
xgb_pred = np.expm1(model_xgb.predict(test))
print(rmsle(y_train, xgb_train_pred))
# Out:
# [22:31:20] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# 0.07988063884791019

# %%
print('RMSLE score on train data:')
print(rmsle(y_train,stacked_train_pred*0.70 +
               xgb_train_pred*0.15 + lgb_train_pred*0.15 ))
# Out:
# RMSLE score on train data:
# 0.07342349620177435

# %%
ensemble = stacked_predict*0.70 + xgb_pred*0.15 + lgb_predict*0.15

# %%
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = ensemble
sub.to_csv('HousePrice.csv',index=False)
