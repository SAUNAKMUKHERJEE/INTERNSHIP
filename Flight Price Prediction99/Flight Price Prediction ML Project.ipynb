# %%
import pandas as pd
import numpy as pd
import time
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
driver=webdriver.Chrome(r"./chromedriver.exe")
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/1150349572.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"./chromedriver.exe")

# %%
url = "https://www.yatra.com/"
driver.get(url)
time.sleep(2)

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=13/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1058058091038"
driver.get(url)
time.sleep(2)

# %%
from tqdm import tqdm
for _ in tqdm (range(0,50)):
    time.sleep(0.1)
    driver.execute_script("window.scrollBy(0,2000)","")
    time.sleep(0.2)
    driver.execute_script("window.scrollBy(0,-500)","")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 50/50 [00:29<00:00,  1.70it/s]

# %%
flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
len(flights)
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/293521711.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
# 25

# %%
Airlines = []
Aeroplane = []
Dept_time = []
Arrival_time = []
Source = []
Destination = []
Duration = []
Stops = []
Date = []
Price = []

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 54.53it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 54.60it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 59.17it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 54.22it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 59.78it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 62.96it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 63.28it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 63.92it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (25, 25, 25, 25, 25, 25, 25, 25, 25, 25)

# %% [markdown]
# 14th august

# %%
url = "https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=13/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=585356744779"
driver.get(url)
time.sleep(2)

# %%
flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
len(flights)
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/293521711.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
# 25

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 64.10it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 55.90it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 55.95it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.30it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 61.86it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 61.02it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 55.51it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.60it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (50, 50, 50, 50, 50, 50, 50, 50, 50, 50)

# %% [markdown]
# 15th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=15/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=803388216288"
driver.get(url)
time.sleep(2)

# %%
flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
len(flights)
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/293521711.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
# 25

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.66it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 64.41it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.27it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.69it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.30it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.09it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.10it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.95it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (75, 75, 75, 75, 75, 75, 75, 75, 75, 75)

# %% [markdown]
# 16th August

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=16/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1640821561648"
driver.get(url)
time.sleep(2)

# %%
flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
len(flights)
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/293521711.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
# 25

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.87it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.26it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 66.56it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 51.98it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.69it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 36.56it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 66.19it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.73it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|███████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 24989.90it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (100, 100, 100, 100, 100, 100, 100, 100, 100, 100)

# %% [markdown]
# 17th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=17/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=980947931606"
driver.get(url)
time.sleep(2)

# %%
flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
len(flights)
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/293521711.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   flights=driver.find_elements_by_xpath('//div[@class="flight-det table full-width clearfix"]')
# 25

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.51it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.57it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.21it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 57.84it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.55it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 45.43it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 42.15it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 48.93it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (125, 125, 125, 125, 125, 125, 125, 125, 125, 125)

# %% [markdown]
# 18th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=18/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1464507431912"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 36.59it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 41.59it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 41.20it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 46.29it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 46.91it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 38.73it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 48.73it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 38.38it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|███████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 24924.55it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (150, 150, 150, 150, 150, 150, 150, 150, 150, 150)

# %% [markdown]
# 19th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=19/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=533881459008"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 45.34it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 42.84it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 41.83it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 34.25it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 47.33it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 55.57it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 47.58it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 39.57it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|███████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 24983.94it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (175, 175, 175, 175, 175, 175, 175, 175, 175, 175)

# %% [markdown]
# 20 august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=20/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=631143402785"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.36it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 39.56it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.62it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.53it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 61.93it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.21it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.64it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.64it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (200, 200, 200, 200, 200, 200, 200, 200, 200, 200)

# %% [markdown]
# 21st august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=21/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1033167548499"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 29.04it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 44.54it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 46.54it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.16it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 57.43it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.20it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 46.95it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.76it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|███████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 24936.41it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (225, 225, 225, 225, 225, 225, 225, 225, 225, 225)

# %% [markdown]
# 22 august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=22/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=153961406567"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 63.12it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 40.23it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.74it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.50it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.94it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 48.77it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.93it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.18it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (250, 250, 250, 250, 250, 250, 250, 250, 250, 250)

# %% [markdown]
# 23rd august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=23/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=754505244465"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.51it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 48.71it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.37it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.29it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 57.77it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.07it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.49it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 55.54it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|███████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 25230.41it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (275, 275, 275, 275, 275, 275, 275, 275, 275, 275)

# %% [markdown]
# 24th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=24/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1152266189937"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 48.51it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.12it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.76it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 65.01it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.20it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.54it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 44.23it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.59it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|███████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 24966.10it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (300, 300, 300, 300, 300, 300, 300, 300, 300, 300)

# %% [markdown]
# 25th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=25/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1351279411962"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 42.80it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 35.35it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.54it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 44.38it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 59.21it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 54.00it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.82it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.70it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (325, 325, 325, 325, 325, 325, 325, 325, 325, 325)

# %% [markdown]
# 26th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=26/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=807000915248"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 44.03it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 51.79it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 47.84it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 44.23it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 43.97it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.72it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.21it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.85it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (350, 350, 350, 350, 350, 350, 350, 350, 350, 350)

# %% [markdown]
# 27th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=27/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=189401203269"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 64.29it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 71.21it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.75it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 73.95it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.10it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 71.62it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 64.75it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.67it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|███████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 24995.85it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (375, 375, 375, 375, 375, 375, 375, 375, 375, 375)

# %% [markdown]
# 28th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=28/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=595495492915"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 59.08it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.40it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.52it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.62it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 59.23it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 62.33it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 64.92it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 66.30it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (400, 400, 400, 400, 400, 400, 400, 400, 400, 400)

# %% [markdown]
# 29th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=29/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=631089146651"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.30it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 45.96it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 42.62it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 54.91it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 45.10it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.47it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.03it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.75it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (425, 425, 425, 425, 425, 425, 425, 425, 425, 425)

# %% [markdown]
# 30th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=29/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=759223557065"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 47.42it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.04it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.94it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 46.03it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 51.53it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.85it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 52.57it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.66it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (450, 450, 450, 450, 450, 450, 450, 450, 450, 450)

# %% [markdown]
# 30th august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=30/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=404942179242"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 41.69it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 32.18it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 57.33it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.67it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.58it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.17it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 61.88it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.35it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (475, 475, 475, 475, 475, 475, 475, 475, 475, 475)

# %% [markdown]
# 31st august

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=31/08/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1241694232002"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 46.43it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 32.68it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 62.02it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 57.82it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 59.70it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.46it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.47it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 46.94it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (500, 500, 500, 500, 500, 500, 500, 500, 500, 500)

# %% [markdown]
# 1st septembar

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=01/09/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=186036452740"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 47.63it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 51.03it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 47.04it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.12it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.69it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.55it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.87it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.80it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (525, 525, 525, 525, 525, 525, 525, 525, 525, 525)

# %% [markdown]
# 2nd September

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=02/09/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1328088021540"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 51.06it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 50.69it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 62.38it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.87it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 28.88it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 46.96it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 48.22it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 59.05it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (550, 550, 550, 550, 550, 550, 550, 550, 550, 550)

# %% [markdown]
# 3rd September

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=03/09/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1152524773368"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 27.74it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 41.00it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 49.40it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 62.05it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 61.02it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 62.05it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 61.34it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 53.26it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|███████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 24989.90it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (575, 575, 575, 575, 575, 575, 575, 575, 575, 575)

# %% [markdown]
# 4th September

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=DEL&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=04/09/2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=867845607376"
driver.get(url)
time.sleep(2)

# %%
airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
for i in airlines:
    Airlines.append(i.text.replace("\n"," "))
else :
    pass

# Extracting Aeroplane model  via xpath
aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
for i in tqdm(aeroplanes):
    Aeroplane.append(i.text) 
else:
    pass

# Extracting Departure Time of Filght via Xpath
dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
for i in tqdm(dept_times):
    Dept_time.append(i.text)
else :
    pass

# Extracting Arrival Time via xpath
arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
for i in tqdm(arrival):
    Arrival_time.append(i.text)
else :
    pass

# Extracting Source of flight via Xpath
source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
for i in tqdm(source):
    Source.append(i.text)
else :
    pass

# Extracting Destination of Flights via Xpath
destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
for i in tqdm(destination):
    Destination.append(i.text)
else:
    pass

# Extracting Duration of Flights via Xpath
duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
for i in tqdm(duration):
    Duration.append(i.text)
else:
    pass

# Extracting stop details via Xpath
stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
for i in tqdm(stop):
    Stops.append(i.text)
else:
    pass

# Extracting Price of Flights via Xpath
count = 0
price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
for i in tqdm(price):
    Price.append(i.text.replace(',',''))
    count = count +1
else:
    count = count +1
    pass

# Clicking on Flights details element
Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,'//div[@class="link-color fs-12 cursor-pointer"]/span'))))
time.sleep(1)

# Extracting Date of Flights via Xpath
date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
a = date.text
for i in tqdm(range(count-1)):
    Date.append(a)
else:
    pass
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   airlines = driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span")
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:8: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   aeroplanes = driver.find_elements_by_xpath('//p[@class="normal fs-11 font-lightestgrey no-wrap fl-no"]/span')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 56.31it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:15: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   dept_times = driver.find_elements_by_xpath('//div[@class="i-b pr"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 65.74it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:22: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   arrival = driver.find_elements_by_xpath('//p[@class="bold fs-15 mb-2 pr time"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 59.93it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:29: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   source = driver.find_elements_by_xpath("//div[@class='i-b col-4 no-wrap text-right dtime col-3']/p")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 60.63it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:36: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   destination = driver.find_elements_by_xpath('//div[@class="i-b pdd-0 text-left atime col-5"]/p[2]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 63.88it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:43: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   duration = driver.find_elements_by_xpath('//div[@class="stop-cont pl-13"]/p')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 58.45it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:50: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   stop = driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/div/span")
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 61.82it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:58: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   price = driver.find_elements_by_xpath('//div[@class="i-b tipsy fare-summary-tooltip fs-18"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<00:00, 40.17it/s]
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:67: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Button = driver.find_elements_by_xpath('//div[@class="link-color fs-12 cursor-pointer"]/span')
# C:\Users\91907\AppData\Local\Temp/ipykernel_41368/201033920.py:72: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   date = driver.find_element_by_xpath('//div[@class="bold fs-12 mb-5"]')
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 25/25 [00:00<?, ?it/s]

# %%
len(Aeroplane), len(Airlines), len(Dept_time), len(Arrival_time), len(Source), len(Destination), len(Duration), len(Stops),len(Price), len(Date)
# Out:
# (600, 600, 600, 600, 600, 600, 600, 600, 600, 600)

# %%
import pandas as pd
import numpy as np

# %%
Flight=pd.DataFrame()
Flight["Airline"]=Airlines
Flight['Aeroplane'] = Aeroplane
Flight["Date"]=Date
Flight["Departure_Time"]=Dept_time
Flight["Arrival_Time"]=Arrival_time
Flight["Source"]=Source
Flight["Destination"]=Destination
Flight["Stops"]=Stops
Flight["Duration"]=Duration
Flight["Price"]=Price

# %%
Flight
# Out:
#        Airline Aeroplane              Date Departure_Time    Arrival_Time  \
# 0      Vistara    UK-975  Sat, 13 Aug 2022          05:55           07:55
# 1      Vistara    UK-927  Sat, 13 Aug 2022          09:30           11:35
# 2     Go First   G8-2501  Sat, 13 Aug 2022          02:40           04:50
# 3      Vistara    UK-951  Sat, 13 Aug 2022          14:20           16:30
# 4      Vistara    UK-933  Sat, 13 Aug 2022          15:30           17:40
# ..         ...       ...               ...            ...             ...
# 595  Air India    AI-805   Sun, 4 Sep 2022          20:00           22:10
# 596  Air India    AI-814   Sun, 4 Sep 2022          22:30  00:40\n+ 1 day
# 597   SpiceJet   SG-8701   Sun, 4 Sep 2022          07:20           09:35
# 598  Air India    AI-678   Sun, 4 Sep 2022          09:00           11:15
# 599  Air India    AI-863   Sun, 4 Sep 2022          14:00           16:15
#
#         Source Destination     Stops Duration Price
# 0    New Delhi      Mumbai  Non Stop   2h 00m  5955
# 1    New Delhi      Mumbai  Non Stop   2h 05m  5955
# 2    New Delhi      Mumbai  Non Stop   2h 10m  5955
# 3    New Delhi      Mumbai  Non Stop   2h 10m  5955
# 4    New Delhi      Mumbai  Non Stop   2h 10m  5955
# ..         ...         ...       ...      ...   ...
# 595  New Delhi      Mumbai  Non Stop   2h 10m  4228
# 596  New Delhi      Mumbai  Non Stop   2h 10m  4228
# 597  New Delhi      Mumbai  Non Stop   2h 15m  4228
# 598  New Delhi      Mumbai  Non Stop   2h 15m  4228
# 599  New Delhi      Mumbai  Non Stop   2h 15m  4228
#
# [600 rows x 10 columns]

# %%
Flight.to_csv('Flight_Price_dataset_2.csv')

# %%
df=Flight

# %%
df
# Out:
#        Airline Aeroplane              Date Departure_Time    Arrival_Time  \
# 0      Vistara    UK-975  Sat, 13 Aug 2022          05:55           07:55
# 1      Vistara    UK-927  Sat, 13 Aug 2022          09:30           11:35
# 2     Go First   G8-2501  Sat, 13 Aug 2022          02:40           04:50
# 3      Vistara    UK-951  Sat, 13 Aug 2022          14:20           16:30
# 4      Vistara    UK-933  Sat, 13 Aug 2022          15:30           17:40
# ..         ...       ...               ...            ...             ...
# 595  Air India    AI-805   Sun, 4 Sep 2022          20:00           22:10
# 596  Air India    AI-814   Sun, 4 Sep 2022          22:30  00:40\n+ 1 day
# 597   SpiceJet   SG-8701   Sun, 4 Sep 2022          07:20           09:35
# 598  Air India    AI-678   Sun, 4 Sep 2022          09:00           11:15
# 599  Air India    AI-863   Sun, 4 Sep 2022          14:00           16:15
#
#         Source Destination     Stops Duration Price
# 0    New Delhi      Mumbai  Non Stop   2h 00m  5955
# 1    New Delhi      Mumbai  Non Stop   2h 05m  5955
# 2    New Delhi      Mumbai  Non Stop   2h 10m  5955
# 3    New Delhi      Mumbai  Non Stop   2h 10m  5955
# 4    New Delhi      Mumbai  Non Stop   2h 10m  5955
# ..         ...         ...       ...      ...   ...
# 595  New Delhi      Mumbai  Non Stop   2h 10m  4228
# 596  New Delhi      Mumbai  Non Stop   2h 10m  4228
# 597  New Delhi      Mumbai  Non Stop   2h 15m  4228
# 598  New Delhi      Mumbai  Non Stop   2h 15m  4228
# 599  New Delhi      Mumbai  Non Stop   2h 15m  4228
#
# [600 rows x 10 columns]

# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
print('No. of Rows :',df.shape[0])
print('No. of Columns :',df.shape[1])
pd.set_option('display.max_columns',None) # This will enable us to see truncated columns
df.head()
# Out:
# No. of Rows : 600
# No. of Columns : 10
#     Airline Aeroplane              Date Departure_Time Arrival_Time  \
# 0   Vistara    UK-975  Sat, 13 Aug 2022          05:55        07:55
# 1   Vistara    UK-927  Sat, 13 Aug 2022          09:30        11:35
# 2  Go First   G8-2501  Sat, 13 Aug 2022          02:40        04:50
# 3   Vistara    UK-951  Sat, 13 Aug 2022          14:20        16:30
# 4   Vistara    UK-933  Sat, 13 Aug 2022          15:30        17:40
#
#       Source Destination     Stops Duration Price
# 0  New Delhi      Mumbai  Non Stop   2h 00m  5955
# 1  New Delhi      Mumbai  Non Stop   2h 05m  5955
# 2  New Delhi      Mumbai  Non Stop   2h 10m  5955
# 3  New Delhi      Mumbai  Non Stop   2h 10m  5955
# 4  New Delhi      Mumbai  Non Stop   2h 10m  5955

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {object: ['Airline', 'Aeroplane', 'Date', 'Departure_Time', 'Arrival_Time', 'Source', 'Destination', 'Stops', 'Duration', 'Price']}

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# Airline           0
# Aeroplane         0
# Date              0
# Departure_Time    0
# Arrival_Time      0
# Source            0
# Destination       0
# Stops             0
# Duration          0
# Price             0
# dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.isnull(), cmap= 'cool_r')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
df['Duration'] = df['Duration'].map(lambda x : x.replace('05m','5m'))

# %%
# Conversion of Duration column from hr & Minutes format to Minutes
df['Duration'] = df['Duration'].str.replace('h','*60').str.replace(' ','+').str.replace('m','*1').apply(eval)

# convert this column into a numeric datatypes
df['Duration']= pd.to_numeric(df['Duration'])

# %%
df['Day']= df['Date'].map(lambda x :x[:3])

# %%
df['Date']= df['Date'].map(lambda x :x[4:])

# %%
Categorical = ['Airline','Day','Stops','Aeroplane']

# %%
pd.set_option('display.max_rows',None)
for i in Categorical :
    print(i)
    print(df[i].value_counts())
    print('='*100)
# Out:
# Airline
# Vistara      216
# IndiGo       142
# Air India     95
# Go First      87
# SpiceJet      53
# Air Asia       7
# Name: Airline, dtype: int64
# ====================================================================================================
# Class
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_41368/1996497451.py in <module>
#       2 for i in Categorical :
#       3     print(i)
# ----> 4     print(df[i].value_counts())
#       5     print('='*100)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Class'

# %% [markdown]
# # EDA

# %%
# Pie & count plot of Airline types
plt.rcParams["figure.autolayout"] = True
sns.set_palette('Set1')
f,ax=plt.subplots(1,2,figsize=(16,8))
df['Airline'].value_counts().plot.pie(autopct='%2.1f%%',
                                          textprops ={ 'fontsize':13,'fontweight' :'bold'}, ax=ax[0],shadow=True)
ax[0].set_title('FlightWise Distribution of Airlines', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Airline',data=df,ax=ax[1])
ax[1].set_title('Airline Vs No of Flights',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Airline",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Flights",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=12,rotation= 90)
plt.tight_layout()
plt.show()

# %%
# Counting No of stops
plt.rcParams["figure.autolayout"] = True
sns.set_palette('hsv')
f,ax=plt.subplots(1,2,figsize=(14,6))
df['Day'].value_counts().plot.pie(autopct='%2.1f%%',
                                          textprops ={ 'fontsize':14,'fontweight' :'bold'}, ax=ax[0],shadow=True)
ax[0].set_title('Day-Wise Distribution of Flights', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('Day',data=df,ax=ax[1])
ax[1].set_title('Day Vs No of Flights',fontsize=18,fontweight ='bold')
ax[1].set_xlabel("Day",fontsize=18,fontweight ='bold')
ax[1].set_ylabel("No. of Flights",fontsize=18,fontweight ='bold')
plt.xticks(fontsize=12,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('mako')
plt.figure(figsize =(14,7))
sns.countplot(x=df['Date'])
plt.title("Date-wise Flight Distribution",fontsize=20,fontweight ='bold')
plt.xlabel('Date',fontsize = 20,fontweight ='bold')
plt.ylabel('No of Flights',fontsize = 20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('mako')
plt.figure(figsize =(12,8))
sns.swarmplot(y=df['Price'],x=df['Stops'], hue= df['Day'])
plt.title("Price VS Stops",fontsize=20,fontweight ='bold')
plt.xlabel('No. of Stop',fontsize = 20,fontweight ='bold')
plt.ylabel('Price',fontsize = 20,fontweight ='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Encoding Categorical Data

# %%
df.drop(columns=['Departure_Time','Arrival_Time','Source','Destination'], inplace= True)

# %%
df.columns.to_series().groupby(df.dtypes).groups
# Out:
# {int64: ['Duration'], object: ['Airline', 'Aeroplane', 'Date', 'Stops', 'Price', 'Day']}

# %%
Categorical = ['Airline', 'Aeroplane', 'Date', 'Stops', 'Day']
Numerical = ['Duration', 'Price']

# %%
df['Aeroplane']= df['Aeroplane'].map(lambda x: str(x).replace('-',''))
df['Aeroplane']= df['Aeroplane'].map(lambda x: str(x).replace('/',''))

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical:
    df[i] =le.fit_transform(df[i])
df.head()
# Out:
#    Airline  Aeroplane  Date  Stops  Duration Price  Day
# 0        5         97     1      1       120  5955    2
# 1        5         80     1      1       125  5955    2
# 2        2         47     1      1       130  5955    2
# 3        5         88     1      1       130  5955    2
# 4        5         84     1      1       130  5955    2

# %% [markdown]
# # Outliers Detection & Removal

# %%
plt.figure(figsize=(15,4), facecolor ='white')
plt_num = 1
for i in Numerical:
    if plt_num <= 2:
        ax = plt.subplot(1,2,plt_num)
        sns.boxplot(df[i], palette='gnuplot')
        plt.xlabel(i, fontsize= 16)
    plt_num += 1
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_41368/1240662225.py in <module>
#       4     if plt_num <= 2:
#       5         ax = plt.subplot(1,2,plt_num)
# ----> 6         sns.boxplot(df[i], palette='gnuplot')
#       7         plt.xlabel(i, fontsize= 16)
#       8     plt_num += 1
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2244                           orient, color, palette, saturation,
#    2245                           width, dodge, fliersize, linewidth)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     404                  width, dodge, fliersize, linewidth):
#     405
# --> 406         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     407         self.establish_colors(color, palette, saturation)
#     408
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     154
#     155             # Figure out the plotting orientation
# --> 156             orient = infer_orient(
#     157                 x, y, orient, require_numeric=self.require_numeric
#     158             )
#
# ~\anaconda3\lib\site-packages\seaborn\_core.py in infer_orient(x, y, orient, require_numeric)
#    1326             warnings.warn(single_var_warning.format("Vertical", "x"))
#    1327         if require_numeric and x_type != "numeric":
# -> 1328             raise TypeError(nonnumeric_dv_error.format("Horizontal", "x"))
#    1329         return "h"
#    1330
#
# TypeError: Horizontal orientation requires numeric `x` variable.

# %%
df.corr()
# Out:
#             Airline  Aeroplane      Date     Stops  Duration       Day
# Airline    1.000000   0.691280 -0.335996  0.082916  0.090168  0.034164
# Aeroplane  0.691280   1.000000 -0.251728  0.095590  0.080169  0.042978
# Date      -0.335996  -0.251728  1.000000 -0.047093 -0.095173  0.058041
# Stops      0.082916   0.095590 -0.047093  1.000000 -0.752676  0.049781
# Duration   0.090168   0.080169 -0.095173 -0.752676  1.000000 -0.035789
# Day        0.034164   0.042978  0.058041  0.049781 -0.035789  1.000000

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),linecolor='black', vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap='gist_stern')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# We can class is highly correlated with target variable Price.
# Most of features are moderately & poorly correlated with each other.

# %%
df.skew()
# Out:
# Airline     -0.271236
# Aeroplane   -0.109291
# Date        -0.030424
# Stops       -1.452500
# Duration     3.514513
# Price       -0.116501
# Day          0.202290
# dtype: float64

# %%
X = df.drop(['Price'], axis=1)
Y = df['Price']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from xgboost import XGBRegressor

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=99, test_size=0.33)
print('Training Feature Matrix Size:', X_train.shape)
print('Training Target Vector Size :', Y_train.shape)
print('Test Feature Matrix Size:', X_test.shape)
print('Test Target Vector Size:', Y_test.shape)
# Out:
# Training Feature Matrix Size: (402, 6)
# Training Target Vector Size : (402,)
# Test Feature Matrix Size: (198, 6)
# Test Target Vector Size: (198,)

# %%
maxR2_score=0
maxRS=0
for i in range(50,500):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.4788492543950815 on Random_state 425

# %%
train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
lin_reg= LinearRegression()
lin_reg.fit(X_train, Y_train)
y_pred = lin_reg.predict(X_test)
print('\033[1m'+ 'Error :'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error :
# Mean absolute error : 2019.6083786887325
# Mean squared error : 4378716.562745068
# Root Mean squared error : 2092.5383061595476
#  R2 Score :
# 1.4525889860702246

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(lin_reg, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',lin_reg,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : LinearRegression() :
#
# Mean CV Score : -824.5278152649935

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
rfc = RandomForestRegressor()
rfc.fit(X_train, Y_train)
y_pred = rfc.predict(X_test)
print('\033[1m'+ 'Error of Random Forest Regressor:'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+'R2 Score of Random Forest Regressor :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error of Random Forest Regressor:
# Mean absolute error : 95.53247474747475
# Mean squared error : 93958.92598535353
# Root Mean squared error : 306.52720268412315
# R2 Score of Random Forest Regressor :
# 97.88536006731132

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(rfc, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',rfc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : -708.6959653098735

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
dtc = DecisionTreeRegressor()
dtc.fit(X_train, Y_train)
y_pred = dtc.predict(X_test)
print('\033[1m'+ 'Error of Decision Tree Regressor:'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+'R2 Score of Decision Tree Regressor :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error of Decision Tree Regressor:
# Mean absolute error : 27.863636363636363
# Mean squared error : 96470.27777777778
# Root Mean squared error : 310.59664804659076
# R2 Score of Decision Tree Regressor :
# 97.82883957466416

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(dtc, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',dtc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : -755.0290020635726

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state= 70, test_size=0.33)
etc = ExtraTreesRegressor()
dtc.fit(X_train, Y_train)
y_pred = dtc.predict(X_test)
print('\033[1m'+ 'Error of Extra Tree Regressor:'+ '\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test, y_pred))
print('Root Mean squared error :', np.sqrt(mean_squared_error(Y_test, y_pred)))
print('\033[1m'+'R2 Score of Extra Tree Regressor :'+'\033[0m')
print(r2_score(Y_test,y_pred)*100)
# Out:
# Error of Extra Tree Regressor:
# Mean absolute error : 27.838383838383837
# Mean squared error : 96468.54545454546
# Root Mean squared error : 310.5938593316768
# R2 Score of Extra Tree Regressor :
# 97.82887856233718

# %%
from sklearn.model_selection import cross_val_score
score = cross_val_score(etc, X_scale, Y, cv=5)
print('\033[1m'+'Cross Validation Score :',etc,":"+'\033[0m\n')
print("Mean CV Score :",score.mean())
# Out:
# Cross Validation Score : ExtraTreesRegressor() :
#
# Mean CV Score : -894.5816573422835

# %%
from sklearn.model_selection import GridSearchCV

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=70, test_size=0.33)

# %%
parameter = {'n_estimators':[400,500],'gamma':np.arange(0,0.2,0.1),
              'booster' : ['gbtree','dart','gblinear'], 'max_depth':[6,8],
              'eta' : [0.01, 0.1] }

# %%
GCV = GridSearchCV(XGBRegressor(),parameter,verbose =10)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV 1/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 1/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.953 total time=   1.6s
# [CV 2/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 2/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.994 total time=   0.1s
# [CV 3/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 3/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.974 total time=   0.2s
# [CV 4/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 4/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.991 total time=   0.1s
# [CV 5/5; 1/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400
# [CV 5/5; 1/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=400;, score=0.974 total time=   0.1s
# [CV 1/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 1/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.960 total time=   0.2s
# [CV 2/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 2/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.999 total time=   0.2s
# [CV 3/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 3/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.980 total time=   0.1s
# [CV 4/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 4/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.996 total time=   0.2s
# [CV 5/5; 2/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500
# [CV 5/5; 2/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=6, n_estimators=500;, score=0.978 total time=   0.2s
# [CV 1/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 1/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.942 total time=   0.1s
# [CV 2/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 2/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.995 total time=   0.1s
# [CV 3/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 3/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.972 total time=   0.1s
# [CV 4/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 4/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.992 total time=   0.1s
# [CV 5/5; 3/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [CV 5/5; 3/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.971 total time=   0.1s
# [CV 1/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 1/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.949 total time=   0.2s
# [CV 2/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 2/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.999 total time=   0.2s
# [CV 3/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 3/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.980 total time=   0.2s
# [CV 4/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 4/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.997 total time=   0.2s
# [CV 5/5; 4/48] START booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [CV 5/5; 4/48] END booster=gbtree, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.976 total time=   0.2s
# [CV 1/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 1/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.953 total time=   0.1s
# [CV 2/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 2/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.994 total time=   0.1s
# [CV 3/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 3/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.974 total time=   0.1s
# [CV 4/5; 5/48] START booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [CV 4/5; 5/48] END booster=gbtree, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0
48] START booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 35/48] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.340 total time=   0.0s
# [CV 4/5; 35/48] START booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 35/48] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.312 total time=   0.0s
# [CV 5/5; 35/48] START booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 35/48] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=400;, score=0.368 total time=   0.0s
# [CV 1/5; 36/48] START booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 36/48] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.190 total time=   0.0s
# [CV 2/5; 36/48] START booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 36/48] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.475 total time=   0.0s
# [CV 3/5; 36/48] START booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 36/48] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.345 total time=   0.0s
# [CV 4/5; 36/48] START booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 36/48] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.317 total time=   0.0s
# [CV 5/5; 36/48] START booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [CV 5/5; 36/48] END booster=gblinear, eta=0.01, gamma=0.0, max_depth=8, n_estimators=500;, score=0.386 total time=   0.0s
# [CV 1/5; 37/48] START booster=gblinear, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 37/48] END booster=gblinear, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.205 total time=   0.0s
# [CV 2/5; 37/48] START booster=gblinear, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 37/48] END booster=gblinear, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.465 total time=   0.0s
# [CV 3/5; 37/48] START booster=gblinear, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 37/48] END booster=gblinear, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400;, score=0.340 total time=   0.0s
# [CV 4/5; 37/48] START booster=gblinear, eta=0.01, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:05] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
# ...
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 44/48] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=8, n_estimators=500;, score=0.337 total time=   0.0s
# [CV 4/5; 44/48] START booster=gblinear, eta=0.1, gamma=0.0, max_depth=8, n_estimators=500
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 44/48] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=8, n_estimators=500;, score=0.321 total time=   0.0s
# [CV 5/5; 44/48] START booster=gblinear, eta=0.1, gamma=0.0, max_depth=8, n_estimators=500
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 44/48] END booster=gblinear, eta=0.1, gamma=0.0, max_depth=8, n_estimators=500;, score=0.403 total time=   0.0s
# [CV 1/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.157 total time=   0.0s
# [CV 2/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.490 total time=   0.0s
# [CV 3/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.337 total time=   0.0s
# [CV 4/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.321 total time=   0.0s
# [CV 5/5; 45/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 45/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=400;, score=0.403 total time=   0.0s
# [CV 1/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [22:45:07] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.157 total time=   0.0s
# [CV 2/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.490 total time=   0.0s
# [CV 3/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.337 total time=   0.0s
# [CV 4/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.321 total time=   0.0s
# [CV 5/5; 46/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 46/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=6, n_estimators=500;, score=0.403 total time=   0.0s
# [CV 1/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.157 total time=   0.0s
# [CV 2/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.490 total time=   0.0s
# [CV 3/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.337 total time=   0.0s
# [CV 4/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.321 total time=   0.0s
# [CV 5/5; 47/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 47/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=400;, score=0.403 total time=   0.0s
# [CV 1/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 1/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.157 total time=   0.0s
# [CV 2/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 2/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.490 total time=   0.0s
# [CV 3/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 3/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.337 total time=   0.0s
# [CV 4/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 4/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.321 total time=   0.0s
# [CV 5/5; 48/48] START booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500
# [22:45:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "gamma", "max_depth" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [CV 5/5; 48/48] END booster=gblinear, eta=0.1, gamma=0.1, max_depth=8, n_estimators=500;, score=0.403 total time=   0.0s
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     gamma=None, gpu_id=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_bin=None,
#                                     max_cat_to_o...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None,
#                                     reg_alpha=None, reg_lambda=None, ...),
#              param_grid={'booster': ['gbtree', 'dart', 'gblinear'],
#                          'eta': [0.01, 0.1], 'gamma': array([0. , 0.1]),
#                          'max_depth': [6, 8], 'n_estimators': [400, 500]},
#              verbose=10)

# %%
pd.DataFrame([model.predict(X_test)[:], Y_test[:]], index = ['Predicted', 'Actual'])
