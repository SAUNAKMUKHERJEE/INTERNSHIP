# %%
import selenium
import pandas as pd
import time
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re
import time

# %% [markdown]
# 9---->

# %%
driver2=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
driver2=webdriver.Chrome("chromedriver.exe")
time.sleep(2)
driver2.get('https://www.imdb.com/list/ls095964455/')
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/3487729216.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver2=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/3487729216.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver2=webdriver.Chrome("chromedriver.exe")

# %%
name=[]
Year_span=[]
Grane=[]
Run_time=[]
Ratings=[]
vote=[]
RUN_time=[]

# %%
titles_tags33=driver2.find_elements_by_xpath("//h3[@class='lister-item-header']")
titles_tags33[0:10]
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/2679158582.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   titles_tags33=driver2.find_elements_by_xpath("//h3[@class='lister-item-header']")
# [<selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="33ac7b9e-edd0-48ce-b80e-3a735e5847ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="64b9645a-cb90-45f4-8118-d1c4c78d4cdd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="7f9c185c-6d8b-44e2-903f-c96ed586f04f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="6cb1b281-947a-4242-bce6-d0c75fc27c7a")>,
# ...

# %%
for i in titles_tags33:
    title33=i.text
    name.append(title33)
name
# Out:
# ['1. Game of Thrones (2011–2019)',
#  '2. Stranger Things (2016– )',
#  '3. The Walking Dead (2010–2022)',
#  '4. 13 Reasons Why (2017–2020)',
#  '5. The 100 (2014–2020)',
#  '6. Orange Is the New Black (2013–2019)',
#  '7. Riverdale (2017–2022)',
#  "8. Grey's Anatomy (2005– )",
#  '9. The Flash (2014– )',
#  '10. Arrow (2012–2020)',
#  '11. Money Heist (2017–2021)',
#  '12. The Big Bang Theory (2007–2019)',
#  '13. Black Mirror (2011–2019)',
#  '14. Sherlock (2010–2017)',
#  '15. Vikings (2013–2020)',
#  '16. Pretty Little Liars (2010–2017)',
#  '17. The Vampire Diaries (2009–2017)',
#  '18. American Horror Story (2011– )',
#  '19. Breaking Bad (2008–2013)',
#  '20. Lucifer (2016–2021)',
#  '21. Supernatural (2005–2020)',
#  '22. Prison Break (2005–2017)',
#  '23. How to Get Away with Murder (2014–2020)',
#  '24. Teen Wolf (2011–2017)',
#  '25. The Simpsons (1989– )',
#  '26. Once Upon a Time (2011–2018)',
#  '27. Narcos (2015–2017)',
#  '28. Daredevil (2015–2018)',
# ...

# %%
tags33=driver2.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
tags33
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/1847771324.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   tags33=driver2.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
# [<selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="864f2da2-0094-4a8f-a66a-7abac1e74fc5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="f1985089-ba1e-4426-8888-38cb9e9c02fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="ada9f595-5376-4110-a570-c2c51b7083dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="3651c3d9-bb9f-4b24-aeb4-c1811b98508b")>,
# ...

# %%
for i in tags33:
    name33=i.text
    Year_span.append(name33)
Year_span
# Out:
# ['(2011–2019)',
#  '(2016– )',
#  '(2010–2022)',
#  '(2017–2020)',
#  '(2014–2020)',
#  '(2013–2019)',
#  '(2017–2022)',
#  '(2005– )',
#  '(2014– )',
#  '(2012–2020)',
#  '(2017–2021)',
#  '(2007–2019)',
#  '(2011–2019)',
#  '(2010–2017)',
#  '(2013–2020)',
#  '(2010–2017)',
#  '(2009–2017)',
#  '(2011– )',
#  '(2008–2013)',
#  '(2016–2021)',
#  '(2005–2020)',
#  '(2005–2017)',
#  '(2014–2020)',
#  '(2011–2017)',
#  '(1989– )',
#  '(2011–2018)',
#  '(2015–2017)',
#  '(2015–2018)',
#  '(1994–2004)',
#  '(2005–2014)',
#  '(2011–2019)',
#  '(2015–2019)',
#  '(2013–2018)',
#  '(2015–2021)',
#  '(2007–2012)',
#  '(2015–2018)',
#  '(2014–2019)',
#  '(2016– )',
#  '(2015–2019)',
#  '(2009–2020)',
#  '(2013– )',
#  '(2016–2019)',
#  '(2017–2019)',
#  '(2013–2018)',
#  '(2017–2020)',
#  '(2018– )',
#  '(2019– )',
#  '(2011–2021)',
#  '(2011–2018)',
#  '(2013–2020)',
#  '(2018– )',
#  '(2006–2013)',
#  '(2015– )',
#  '(1999– )',
#  '(2013– )',
#  '(2004–2010)',
#  '(2013–2022)',
# ...

# %%
titles=driver2.find_elements_by_xpath("//span[@class='genre']")
titles
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/1616123970.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   titles=driver2.find_elements_by_xpath("//span[@class='genre']")
# [<selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="2b5e01a0-279c-415b-9859-0ab9f7a1ef86")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="e79908d7-3bd4-404f-a903-70d4f95fcb2c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="f2f2efdc-4df6-46a0-b81e-4b3b0f99d907")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="f10a73a2-b5e6-458c-a6b2-39a401ca3d8b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="fd0d3cc5-6fef-4dcd-a07a-00d7cf76fd31")>,
# ...

# %%
for i in titles:
    title331=i.text
    Grane.append(title331)
Grane
# Out:
# ['Action, Adventure, Drama',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Thriller',
#  'Drama, Mystery, Thriller',
#  'Drama, Mystery, Sci-Fi',
#  'Comedy, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Drama, Romance',
#  'Action, Adventure, Drama',
#  'Action, Adventure, Crime',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Drama, Mystery, Sci-Fi',
#  'Crime, Drama, Mystery',
#  'Action, Adventure, Drama',
#  'Drama, Mystery, Romance',
#  'Drama, Fantasy, Horror',
#  'Drama, Horror, Sci-Fi',
#  'Crime, Drama, Thriller',
#  'Crime, Drama, Fantasy',
#  'Drama, Fantasy, Horror',
#  'Action, Crime, Drama',
#  'Crime, Drama, Mystery',
#  'Action, Drama, Fantasy',
#  'Animation, Comedy',
#  'Adventure, Fantasy, Romance',
#  'Biography, Crime, Drama',
#  'Action, Crime, Drama',
#  'Comedy, Romance',
#  'Comedy, Romance',
#  'Comedy, Drama',
#  'Crime, Drama, Thriller',
#  'Drama, Fantasy, Horror',
#  'Action, Adventure, Drama',
#  'Drama, Romance',
#  'Drama, Mystery, Sci-Fi',
# ...

# %%
timee=driver2.find_elements_by_xpath("//span[@class='runtime']")
timee
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/4074122474.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   timee=driver2.find_elements_by_xpath("//span[@class='runtime']")
# [<selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="df3e7255-d443-49c9-8a40-80ca548f069e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="68f59092-31a4-4a20-8036-dffc904e32b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="322c5069-1c6e-4038-828d-c45b1d2ff0d7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="c6161c4f-2976-43cf-b5d1-f383289070cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="b2e7605f-5ac1-4aee-8214-0f7665da45e7")>,
# ...

# %%
for i in timee:
    name3=i.text
    RUN_time.append(name3)
RUN_time
# Out:
# ['57 min',
#  '51 min',
#  '44 min',
#  '60 min',
#  '43 min',
#  '59 min',
#  '45 min',
#  '41 min',
#  '43 min',
#  '42 min',
#  '70 min',
#  '22 min',
#  '60 min',
#  '88 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '60 min',
#  '49 min',
#  '42 min',
#  '44 min',
#  '44 min',
#  '43 min',
#  '41 min',
#  '22 min',
#  '60 min',
#  '49 min',
#  '54 min',
#  '22 min',
#  '22 min',
#  '44 min',
#  '49 min',
#  '45 min',
#  '43 min',
#  '42 min',
#  '60 min',
#  '42 min',
#  '62 min',
#  '56 min',
#  '22 min',
#  '23 min',
#  '42 min',
#  '25 min',
#  '51 min',
#  '60 min',
#  '60 min',
#  '45 min',
#  '46 min',
#  '22 min',
#  '45 min',
#  '45 min',
#  '53 min',
#  '44 min',
#  '22 min',
#  '43 min',
#  '44 min',
#  '60 min',
#  '44 min',
#  '42 min',
#  '44 min',
#  '55 min',
#  '42 min',
#  '42 min',
#  '60 min',
#  '60 min',
#  '41 min',
#  '60 min',
#  '44 min',
#  '22 min',
#  '22 min',
#  '43 min',
#  '60 min',
#  '55 min',
#  '60 min',
#  '45 min',
#  '46 min',
# ...

# %%
title=driver2.find_elements_by_xpath("//span[@class='ipl-rating-star__rating']")
title
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/789218527.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   title=driver2.find_elements_by_xpath("//span[@class='ipl-rating-star__rating']")
# [<selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="c17a19b7-1e67-4069-8baf-7b49742b656a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="a087df3b-453c-4bc6-a0c8-9aae7102da3c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="51c3faa8-ad5b-4c4e-b9f8-2aae3498f85c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="e7e42526-5b1f-4a55-9c91-587040cb1e82")>,
# ...

# %%
for i in title:
    name13=i.text
    Ratings.append(name13)
Ratings
# Out:
# ['9.2',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8.7',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8.2',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7.5',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7.6',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '8.1',
#  '',
#  'Rate',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
t=driver2.find_elements_by_xpath("//div[@class='wtw-option-standalone']")
t
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/1540214713.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   t=driver2.find_elements_by_xpath("//div[@class='wtw-option-standalone']")
# [<selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="34aca526-c8db-4b1e-ba8f-57973e85a142")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="3b7fa97e-76a1-4af8-9922-15278d3c312b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="bd228fcb-2114-428e-862f-dad6fde4212c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="d7249ab6-b133-47e4-afbc-2400f3a5911b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="84be624dd9946b783c77e613783bddd1", element="453c7cc9-bac2-4aa6-b4cc-ef35bb462cd9")>,
# ...

# %%
for i in t:
    name30=i.text
    vote.append(name30)
vote
# Out:
# ['created - 10 Oct 2019',
#  'updated - 10 Oct 2019',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
#  'Votes:',
# ...

# %% [markdown]
# 7-->

# %%
driver=webdriver.Chrome("chromedriver.exe")
time.sleep(2)
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/1659935237.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("chromedriver.exe")

# %%
driver.get('https://www.naukri.com/')

# %%
search_field_desingnation=driver.find_element_by_class_name("suggestor-input")#job search bar
search_field_desingnation.send_keys("Data Science")
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/2238071226.py:1: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   search_field_desingnation=driver.find_element_by_class_name("suggestor-input")#job search bar

# %%
search_field_location=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")#job search bar
search_field_location.send_keys("Bangalore")
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/2871844924.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_field_location=driver.find_element_by_xpath("/html/body/div[1]/div[2]/div[3]/div/div/div[5]/div/div/div/input")#job search bar

# %%
search_button=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")
search_button.click()
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/102377290.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_button=driver.find_element_by_xpath("/html/body/div/div[2]/div[3]/div/div/div[6]")

# %%
job_titles=[]
company_names=[]
locations_list=[]
skills=[]
experience_list=[]

# %%
titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
titles_tags
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/2238530929.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   titles_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
# [<selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="2d74b063-8448-43d9-9568-3cfe3b303569")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="ff97aeed-7c2d-461d-8335-18684f4a210c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="fbaa058f-6012-45b4-afb2-c66c411a7d85")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="870c842e-d85b-4fc9-b4ec-25040fb9a079")>,
# ...

# %%
for i in titles_tags:
    title=i.text
    job_titles.append(title)
job_titles
# Out:
# ['Senior Analyst, Data Science',
#  'Data Analysis / Data Science',
#  'Data Science Analyst',
#  'Team Lead/Consultant-Data Science',
#  'Technical Analyst ( Python - Data Science and Machine Learning )',
#  'Senior Analyst-Data Science',
#  'Senior Data Science Engineer',
#  'Data Science Consultant',
#  'Data Science - Sr.Consultant/Manager',
#  'Senior Advisor, Data Science',
#  'Manager Data Science',
#  'HCL || Data Science',
#  'Data Science Consultant - Java / SQL / Python',
#  'Data Science - Contract To Hire',
#  'Data Science Engineer - IIT/NIT/BITS',
#  'Data Science - Engineering Manager',
#  'Group Manager - Data Science',
#  'Data Science Advisor',
#  'Consultant/Senior Manager - Analytics/Data Science - IT',
#  'Sr. Lead -Data Science']

# %%
companies_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
companies_tags
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/3741021800.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   companies_tags=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")
# [<selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="bea58430-aa36-4365-b121-b4cbef937344")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="0e198e62-296c-4727-8391-f5654e14a106")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="f01d799b-cd30-4692-aeaf-2252f6015b7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="3fdd6604-5078-429e-b860-06e3c457f495")>,
# ...

# %%
for i in companies_tags:
    company_name=i.text
    company_names.append(company_name)
company_names
# Out:
# ['Dell Technologies',
#  'Naukri Premium - Employer Services',
#  'Shell',
#  'Accenture',
#  'Coforge',
#  'Accenture',
#  'Fractal Analytics',
#  'Allstate Solutions (ASPL)',
#  'EY',
#  'Dell Technologies',
#  'SYMPHONY EYC INDIA PRIVATE LIMITED',
#  'HCL Technologies',
#  'Altimax Business Solutions',
#  'Successr HR Tech PVT LTD',
#  'TalentStack',
#  'Paytm',
#  'Quality Matrix Inc',
#  'Dell Technologies',
#  'Huquo Consulting Pvt. Ltd',
#  'Selective Global Search Pvt. Ltd.']

# %%
job_location=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")
job_location
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/1284271165.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   job_location=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")
# [<selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="ae8564f6-cb81-4283-9388-1bb0129ed2fc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="47c19ea0-fe90-4a33-ba1a-8e357327585d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="d3e89281-a7e4-49c7-a36a-3e1b02fa543f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="8e8d76cf-e30e-4f59-b116-e5e98f259ced")>,
# ...

# %%
for i in job_location:
    location=i.text
    locations_list.append(location)
locations_list
# Out:
# ['Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Greater Noida',
#  'Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Remote',
#  'Chennai, Bangalore/Bengaluru, Delhi / NCR',
#  'Mumbai, Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  '(WFH during Covid)',
#  'Bangalore/Bengaluru',
#  'Noida, Mumbai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru, Mumbai (All Areas)',
#  'Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru, Greater Noida',
#  'Bangalore/Bengaluru',
#  'Gurgaon/Gurugram, Bangalore/Bengaluru, Mumbai (All Areas)',
# ...

# %%
job_skills=driver.find_elements_by_xpath("//ul[@class='tags has-description']")
job_skills
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/2228134470.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   job_skills=driver.find_elements_by_xpath("//ul[@class='tags has-description']")
# [<selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="58eae589-2ad2-419e-b1ac-a565502cd2b2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="76354618-b62a-45a9-a2e1-94dbc8197cba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="19840db6-911a-41f7-b9e0-fda904be67eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fba6e294875cada97b0962185c07d9a7", element="09a24c6a-1983-4492-87ec-e97dfa2efd1c")>,
# ...

# %%
for i in job_skills:
    location11=i.text
    skills.append(location11)
skills
# Out:
# ['SQL\nIT Skills\nPython\nData Science\nMachine Learning\nBig Data\nTableau\nRegression techniques',
#  'data analysis\nbig data analytics\nConjoint\nTurf Analyses\nMax diff\nMachine Learning\nSAS\ncommunication',
#  'Data Science\nData Science Analyst\ndata analysis',
#  'customer analytics\nPublishing\nArchitecture\ndata science\nConsulting\nMachine learning\nPredictive modeling\nData mining',
#  'python\nIT Skills\nData Science\nMachine Learning\nCloud',
#  'Publishing\nConsulting\nPredictive modeling\nData mining\nAnalytics\nIT Skills\nData Science\nMachine Learning',
#  'Data Science\nIT Skills\nPython\nMachine Learning\nArtificial Intelligence\nNatural Language Processing',
#  'Data Science\nIT Skills\nPython\nSoftware Development\nTesting\nMachine Learning\nOracle\nTableau',
#  'data science\npython\nr\nsql',
#  'PostgreSQL\nSQL Server\nOracle\nIT Skills\nPython\nTesting\nData Science\nMachine Learning',
# ...

# %% [markdown]
# 2--->

# %%
driver3=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
driver3=webdriver.Chrome("chromedriver.exe")
time.sleep(2)
driver3.get('https://www.bcci.tv/')
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/3634474868.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver3=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/3634474868.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver3=webdriver.Chrome("chromedriver.exe")

# %%
Matches=[]
Vaneu=[]

# %%
Match_title=driver3.find_elements_by_xpath("//span[@class='ng-binding']")
Match_title
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/3421808622.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Match_title=driver3.find_elements_by_xpath("//span[@class='ng-binding']")
# [<selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="69da44f6-6c34-423d-bcb3-a341932f5219")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="8391b329-0560-4253-83f5-ff6c40818be7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="b488de79-a480-4cef-80f1-0e9e9dd306fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="21a8523e-31a0-46f4-91cc-2f0b7dd2f925")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="11c6e694-9984-4e3a-8e19-f447a002bcf7")>,
# ...

# %%
for i in Match_title:
    m=i.text
    Matches.append(m)
Matches
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'England VS India',
#  'EDGBASTON',
#  '',
#  '',
#  '',
#  '']

# %%
Location=driver3.find_elements_by_xpath("//span[@class='ng-binding']")
Location
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/3394774824.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Location=driver3.find_elements_by_xpath("//span[@class='ng-binding']")
# [<selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="69da44f6-6c34-423d-bcb3-a341932f5219")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="8391b329-0560-4253-83f5-ff6c40818be7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="b488de79-a480-4cef-80f1-0e9e9dd306fd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="21a8523e-31a0-46f4-91cc-2f0b7dd2f925")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="87d5dd1132fd454f57d34f0daad7e28c", element="11c6e694-9984-4e3a-8e19-f447a002bcf7")>,
# ...

# %%
for i in Location:
    location121=i.text
    Vaneu.append(location121)
Vaneu
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'England VS India',
#  'EDGBASTON',
#  '',
#  '',
#  '',
#  '']

# %%
Location=driver3.find_elements_by_xpath("//span[@class='ng-binding']")
Location
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/3394774824.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Location=driver3.find_elements_by_xpath("//span[@class='ng-binding']")
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30392/3394774824.py in <module>
# ----> 1 Location=driver3.find_elements_by_xpath("//span[@class='ng-binding']")
#       2 Location
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     542             stacklevel=2,
#     543         )
# --> 544         return self.find_elements(by=By.XPATH, value=xpath)
#     545
#     546     def find_element_by_link_text(self, link_text) -> WebElement:
#
# ...

# %% [markdown]
# 5---->

# %%
driver3=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
driver3=webdriver.Chrome("chromedriver.exe")
time.sleep(2)
driver3.get('https://github.com/')
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/698244260.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver3=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/698244260.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver3=webdriver.Chrome("chromedriver.exe")

# %%
repository_name=[]
language_used=[]

# %%
title=driver3.find_elements_by_xpath("//div[@class='wb-break-word']")
title
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/2142040264.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   title=driver3.find_elements_by_xpath("//div[@class='wb-break-word']")
# [<selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="01679aac-7a9d-48d1-a174-25e9f54b1773")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="5a23a0f1-f92d-481a-be47-5034934647ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="386621da-1494-4644-bd77-a0ccf2138308")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="bab0facb-e47e-4737-bd3b-8201c535c759")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="8b723519-f95e-4204-8404-a96919a3f520")>,
# ...

# %%
for i in title:
    l1=i.text
    repository_name.append(l1)
repository_name
# Out:
# ['SAUNAKMUKHERJEE/INTERNSHIP',
#  'SAUNAKMUKHERJEE/PRACTICE-PROJECTSOUNAK',
#  'SAUNAKMUKHERJEE/datatrained',
#  'SAUNAKMUKHERJEE/SAUNAKMUKHERJEE',
#  'SAUNAKMUKHERJEE/Stats',
#  'SAUNAKMUKHERJEE/PRACTICE-PROJECT',
#  'SAUNAKMUKHERJEE/Final-project',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
Language=driver3.find_elements_by_xpath("//div[@class='f6 color-fg-muted mt-2']")
Language
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_30392/1977696615.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   Language=driver3.find_elements_by_xpath("//div[@class='f6 color-fg-muted mt-2']")
# [<selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="08b58e45-f147-4e31-af08-b71c71d45623")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="01fb7c41-d53e-43f3-b39e-db7544a8f0b5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="2fdba1f2-937b-4dbc-9903-fc374420768d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="79f024e22e8d029a4df1b3989af24002", element="86b417f1-ac72-4cd5-8242-e6b64e7ad6b2")>,
# ...

# %%
for i in Language:
    l12=i.text
    language_used.append(l12)
language_used
# Out:
# ['Jupyter Notebook Updated 18 hours ago',
#  'Updated 9 days ago',
#  'Jupyter Notebook Updated 15 days ago',
#  'Jupyter Notebook Updated 19 days ago',
#  'Updated on May 22',
#  'Updated on Apr 11',
#  'Updated on Apr 11']

# %% [markdown]
# 2-->

# %%
driver32=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
driver32=webdriver.Chrome("chromedriver.exe")
time.sleep(2)
driver32.get('https://www.guru99.com/')
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_26276/4161136084.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver32=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
# C:\Users\91907\AppData\Local\Temp/ipykernel_26276/4161136084.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver32=webdriver.Chrome("chromedriver.exe")

# %%
search_field_desingnation=driver32.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]")#job search bar
search_field_desingnation.send_keys("Python")
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_26276/2968495016.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_field_desingnation=driver32.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]")#job search bar
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26276/2968495016.py in <module>
#       1 search_field_desingnation=driver32.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]")#job search bar
# ----> 2 search_field_desingnation.send_keys("Python")
#
# ...

# %%
search_button=driver32.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button/svg")
search_button.click()
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_26276/3557781383.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   search_button=driver32.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button/svg")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26276/3557781383.py in <module>
# ----> 1 search_button=driver32.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button/svg")
#       2 search_button.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     519             stacklevel=2,
#     520         )
# ...

# %% [markdown]
# 6--->

# %%
driver3=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
driver3=webdriver.Chrome("chromedriver.exe")
time.sleep(2)
driver3.get('https:/www.billboard.com/')
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_17300/3302663371.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver3=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
# C:\Users\91907\AppData\Local\Temp/ipykernel_17300/3302663371.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver3=webdriver.Chrome("chromedriver.exe")

# %%
name=[]

# %%
song_name=driver3.find_elements_by_xpath("//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']")
song_name
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_17300/1568167251.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   song_name=driver3.find_elements_by_xpath("//ul[@class='lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max']")
# [<selenium.webdriver.remote.webelement.WebElement (session="8f8e6fe0a13dcf4ce6159b260b5acdc9", element="8ba23b7a-657d-45ce-9f38-541ba5ffb838")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8f8e6fe0a13dcf4ce6159b260b5acdc9", element="aeaaebd0-5393-431f-bf5b-560278f01e68")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8f8e6fe0a13dcf4ce6159b260b5acdc9", element="a2b7aa21-c155-4cc0-b72f-c360c13a07be")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="8f8e6fe0a13dcf4ce6159b260b5acdc9", element="c24e2f36-1aaf-4512-931d-f6c23a42b3b5")>,
# ...

# %%
for i in song_name:
    l52=i.text
    name.append(l52)
name[0:100]
# Out:
# ['As It Was\nHarry Styles\n1\n1\n11',
#  'First Class\nJack Harlow\n2\n1\n10',
#  'Wait For U\nFuture Featuring Drake & Tems\n3\n1\n7',
#  'About Damn Time\nLizzo\n5\n4\n9',
#  'Running Up That Hill (A Deal With God)\nKate Bush\n4\n4\n23',
#  'Heat Waves\nGlass Animals\n6\n1\n74',
#  'Big Energy\nLatto\n7\n3\n34',
#  'Me Porto Bonito\nBad Bunny & Chencho Corleone\n8\n7\n6',
#  'Titi Me Pregunto\nBad Bunny\n10\n5\n6',
#  'Glimpse Of Us\nJoji\n-\n10\n1',
#  'Wasted On You\nMorgan Wallen\n13\n9\n31',
#  'Stay\nThe Kid LAROI & Justin Bieber\n11\n1\n49',
#  'Yet To Come\nBTS\n-\n13\n1',
#  'I Like You (A Happier Song)\nPost Malone Featuring Doja Cat\n9\n9\n2',
#  'Late Night Talking\nHarry Styles\n15\n4\n4',
#  'Boyfriend\nDove Cameron\n17\n16\n18',
#  'Ghost\nJustin Bieber\n16\n5\n38',
#  'Enemy\nImagine Dragons X JID\n14\n5\n30',
#  'Numb Little Bug\nEm Beihold\n21\n19\n20',
#  'Bad Habits\nEd Sheeran\n19\n2\n51',
#  'Moscow Mule\nBad Bunny\n18\n4\n6',
# ...

# %%
driver32=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
driver32=webdriver.Chrome("chromedriver.exe")
time.sleep(2)
driver32.get('https://archive.ics.uci.edu/')
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_17300/2499885924.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver32=webdriver.Chrome(r"C:\Users\91907\chromedriver.exe")
# C:\Users\91907\AppData\Local\Temp/ipykernel_17300/2499885924.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver32=webdriver.Chrome("chromedriver.exe")

# %%
name=driver3.find_elements_by_xpath("//p[@class='normal']")
name
# Out:
# C:\Users\91907\AppData\Local\Temp/ipykernel_17300/386969972.py:1: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   name=driver3.find_elements_by_xpath("//p[@class='normal']")
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17300/386969972.py in <module>
# ----> 1 name=driver3.find_elements_by_xpath("//p[@class='normal']")
#       2 name
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements_by_xpath(self, xpath)
#     542             stacklevel=2,
#     543         )
# --> 544         return self.find_elements(by=By.XPATH, value=xpath)
#     545
#     546     def find_element_by_link_text(self, link_text) -> WebElement:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_elements(self, by, value)
# ...
